# %% [markdown]
# # README
#
# #### **Goal**
# The goal of this project was to identify any year-over-year trends for the top universities/colleges ranked in [Forbes' 2023 America's Top Colleges](https://www.forbes.com/top-colleges/) list - comparing rates of total endoment to rates of total undergraduate enrollment and total undergraduate first-time admittance. More specifically, gauging whether an increase in total endowment correlated to an increase in either total enrollment or first-time admittance. "Top universities/colleges" alluded to in the analysis are comprised of the top 10 universities/colleges listed in Forbes' rankings. Columbia University (6th on the list) was excluded throughout in-depth analysis due to incomplete data, being replaced by the inclusion of Amherst College (11th on the list). Total endowments were gathered from relative financial sources for each university/college, while the rates of total enrollments & admissions were mainly gathered from a relative Common Data Set (CDS). The timeline of analysis was decided for the year range 2019-2023. All source listings can be found [here](https://docs.google.com/spreadsheets/d/1Uaxu700eytkzg8kkCj1nVMXiTj0RdxPKqeJLKu9mH4E/edit?usp=sharing).
#
#
# #### **University/College Insights**
# Generally, there seemed to be few patterns of trends in Total Endowment vs. Undergraduate Enrollment and Undergraduate Admissions. Most notably, 90% of universities saw an increase in endowment for the years beginning 2019 & 2020, with this trend seeming to change during the following period of 2021-2022 - observing that 60% of universities had a decrease in Total Endowment. However, when observing the Total Endowments on a case-by-case basis, 70% of universities/colleges experienced a relatively large increase from 2020-2021. Furthermore, within 2020-2021, Admission rates experienced a decrease in most universities/colleges. *For insights on Admission rates, also see 'Curious Analysis' section.*
#
# 1) Princeton doesn't seem to follow a correlation trend. It saw its comparitively biggest endowment increase at 43.8% from 2020-2021, with its relatively largest total enrollment rate at 11.77%. Even though the total endowment increased, admissions during this time period decreased by almost 11%, but drastically picked up by 31% from 2021-2022.
#
# 2) Yale seems to have undegone a reciprocal increase/decrease pattern for total endowment and total enrollment, with total admittance following neither trend. It saw its biggest total endowment increase from 2021-2022 at 35.5%, with only a 1.67% increase in enrollment for the same year - admittance slowed during this period with an 8.77% decrease. Interestingly, the period prior (2020-2021) saw a 2.9% endowment increase, with the relatively largest enrollment increase at 38.98%.
#
# 3) Stanford doesn't seem to undergo any correlation trends. Although unlike Princeton and Yale, Stanford saw its largest endowment increase from 2020-2021 at 70.4%, with a coinciding largest increase in enrollment for the same time period at 20.09%; however, during the same time period for admittance, there was a 6% decrease.
#
# 4) MIT doesn't seem to undergo any ubiquitious correlation trends. There is an observed increase for both total endowment and total enrollment for the periods 2020-2021 & 2021-2022, but total admittance observed a decrease for both. MIT saw its comparitively largest endowment increase at 48.9% from 2021-2022, with a .41% increase in enrollment for the same year; 2020-2021 having the largest enrollment increase at 6.35%. During the largest endowment period (2021-2022), there was an observed 6% decrease in admittance, with a subsequent decrease for the last remaining time period.
#
# 5) University of California, Berkeley (UCB) seemed to follow a pattern where an increase/decrease in total endowment also correlated with an increase/decrease in total admittance. Total enrollment strayed from this pattern by indicating a decrease from 2019-2020, with subsequent enrollment increases throughout the remaining periods.
#
# 6) UCLA displayed an increase in total enrollment for all time periods with its total endowment generally increasing, 2021-2022 displaying a 1.96% decrease for the latter. Even though there was a ubiquitious increase in enrollment, total admittance generally decreased - with 2019-2020 being the only increase at 16.16%.
#
# 7) UPenn saw total endowment increases for all time periods shown. The largest endowment increase occurred from 2020-2021 at 37.58%. Although there were consistent endowment increases, there were still total enrollment decreases from 2019-2020 and 2021-2022 - with total admittance decreases from 2020-2021 and 2022-2023.The largest total enrollment increase occurred from 2022-2023 at 2.41%.
#
# 8) Harvard showed a coorelated increase/decrease pattern for all time periods when comparing total endowment to total first-time admittance - with the largest endowment increase being observed during 2020-2021 at a 26.97% increase, and the largest admittance increase during this same period being at 15.04%. Total enrollment also saw its largest increase during the same 2020-2021 period at 36.98%, however its general trend does not follow the same endowment:admittance observations.
#
# 9) Williams seems to follow a coorelated increase/decrease pattern, in regard to total endowment vs. total enrollment, for all time periods - with the only increase being observed during the 2020-2021 period. Although there was an observed 0% change from 2022-2023, Williams saw its largest total endowment increase of 50% from 2020-2021. During the same 2020-2021 period, William's largest total enrollment increase was observed at 10.4%.
#
# 10) Amherst doesn't seem to follow a coorelation trend - although its largest total endowment change is observed from 2020-2021 at a 46.98% increase, with the largest total enrollment change occurring during the same period at a 12.95% increase. However, during this same time period, admittance rates decreased.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
raw_df = pd.read_csv('/kaggle/input/cleaned-forbes/cleaned-forbes.csv')

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ranking-2023            55 non-null     int64
#  1   university              55 non-null     object
#  2   state                   55 non-null     object
#  3   type                    55 non-null     object
#  4   endowment-fy-begin      55 non-null     int64
#  5   endowment-amount        55 non-null     int64
#  6   ug-enrollment-year      55 non-null     int64
#  7   ug-enrolled-total       55 non-null     int64
#  8   ug-first-time-enrolled  55 non-null     object
#  9   ug-first-time-admitted  55 non-null     object
# dtypes: int64(5), object(5)
# memory usage: 4.4+ KB

# %%
raw_df['ug-first-time-enrolled'] = pd.to_numeric(raw_df['ug-first-time-enrolled'], errors='coerce')

# %%
raw_df['ug-first-time-admitted'] = pd.to_numeric(raw_df['ug-first-time-admitted'], errors='coerce')

# %%
raw_df.shape
# Out:
# (55, 10)

# %%
raw_df.dtypes
# Out:
# ranking-2023                int64
# university                 object
# state                      object
# type                       object
# endowment-fy-begin          int64
# endowment-amount            int64
# ug-enrollment-year          int64
# ug-enrolled-total           int64
# ug-first-time-enrolled    float64
# ug-first-time-admitted    float64
# dtype: object

# %%
raw_df.head()
# Out:
#    ranking-2023            university state                    type  \
# 0             1  Princeton University    NJ  Private-not-for-profit
# 1             1  Princeton University    NJ  Private-not-for-profit
# 2             1  Princeton University    NJ  Private-not-for-profit
# 3             1  Princeton University    NJ  Private-not-for-profit
# 4             1  Princeton University    NJ  Private-not-for-profit
#
#    endowment-fy-begin  endowment-amount  ug-enrollment-year  \
# 0                2023       35800000000                2023
# 1                2022       37700000000                2022
# 2                2021       26200000000                2021
# 3                2020       26100000000                2020
# 4                2019       25900000000                2019
#
#    ug-enrolled-total  ug-first-time-enrolled  ug-first-time-admitted
# 0               5598                  1366.0                  1782.0
# ...

# %% [markdown]
# # Reviewing NaNs
# 1. Columbia
#     - Columbia university (ranked 6) contains NaN due to no publicly availabile CDS records, for the years (2023, 2020, 2019)
#
# - Due to aforementioned, I will remove these records from calculations
#     - This has been mitigated by the inclusion of CDS metadata for Amherst College (rank 11)

# %%
raw_df[raw_df['ug-first-time-enrolled'].isna()]
# Out:
#     ranking-2023           university state                    type  \
# 25             6  Columbia University    NY  Private not-for-profit
# 28             6  Columbia University    NY  Private not-for-profit
# 29             6  Columbia University    NY  Private not-for-profit
#
#     endowment-fy-begin  endowment-amount  ug-enrollment-year  \
# 25                2023       13643000000                2023
# 28                2020       11257000000                2020
# 29                2019       10951000000                2019
#
#     ug-enrolled-total  ug-first-time-enrolled  ug-first-time-admitted
# 25               9704                     NaN                     NaN
# 28               8842                     NaN                     NaN
# 29               9001                     NaN                     NaN

# %%
# checking amount of NaNs in column
raw_df[raw_df['ug-first-time-enrolled'].isna()].shape
# Out:
# (3, 10)

# %%
# checking sum of NaNs in raw_df
raw_df.isna().any(axis=1).sum()
# Out:
# 3

# %%
# checking Amherst for verification
raw_df[raw_df.university == 'Amherst College']
# Out:
#     ranking-2023       university state                    type  \
# 50            11  Amherst College    MA  Private not-for-profit
# 51            11  Amherst College    MA  Private not-for-profit
# 52            11  Amherst College    MA  Private not-for-profit
# 53            11  Amherst College    MA  Private not-for-profit
# 54            11  Amherst College    MA  Private not-for-profit
#
#     endowment-fy-begin  endowment-amount  ug-enrollment-year  \
# 50                2023        4060000000                2023
# 51                2022        4040000000                2022
# 52                2021        4630000000                2021
# 53                2020        3150000000                2020
# 54                2019        2473000000                2019
#
#     ug-enrolled-total  ug-first-time-enrolled  ug-first-time-admitted
# 50               1907                   488.0                  1250.0
# 51               1898                   467.0                  1079.0
# ...

# %%
# creating new df without NaNs
clean_df = raw_df[raw_df.university != 'Columbia University'].copy()

# %%
# checking for any remaining NaNs 
clean_df.isna().any(axis=1).sum()
# Out:
# 0

# %%
# suppress scientific notation by setting float_format
pd.options.display.float_format = '{:.0f}'.format

# %% [markdown]
# # Creating Relative DataFrames

# %%
# setting float formatting to 4 decimal places for displaying pct_change
pd.options.display.float_format = '{:,.4f}'.format

# %% [markdown]
# #### **Princeton**

# %%
princeton_df = clean_df[clean_df.university == 'Princeton University'].sort_values(by=['endowment-fy-begin']).copy()

# %%
# adds column to calculate YoY difference of endowment
princeton_df['end-yoy-diff'] = princeton_df['endowment-amount'].diff()

# %%
# adds column to calculate YoY difference of ug-enrolled-total variable
princeton_df['ug-enrtotal-yoy-diff'] = princeton_df['ug-enrolled-total'].diff()

# %%
# adds column to calculate YoY difference of ug-first-time-enrolled variable
princeton_df['ug-first-time-enr-yoy-diff'] = princeton_df['ug-first-time-enrolled'].diff()

# %%
# adds column to calculate YoY difference of ug-first-time-admitted variable
princeton_df['ug-first-time-adm-yoy-diff'] = princeton_df['ug-first-time-admitted'].diff()

# %%
# adds column to calculate pct change of endowment-amount
princeton_df['endowment-pct-chg'] = princeton_df['endowment-amount'].pct_change()

# %%
# adds column to calculate pct change of ug-enrolled-total
princeton_df['ugtotal-pct-chg'] = princeton_df['ug-enrolled-total'].pct_change()

# %%
# adds column to calculate pct change of ug-first-time-enrolled
princeton_df['ugfirst-time-pct-chg'] = princeton_df['ug-first-time-enrolled'].pct_change()

# %%
# adds column to calculate pct change of ug-first-time-admitted
princeton_df['ug-admitted-pct-chg'] = princeton_df['ug-first-time-admitted'].pct_change()

# %%
princeton_df
# Out:
#    ranking-2023            university state                    type  \
# 4             1  Princeton University    NJ  Private-not-for-profit
# 3             1  Princeton University    NJ  Private-not-for-profit
# 2             1  Princeton University    NJ  Private-not-for-profit
# 1             1  Princeton University    NJ  Private-not-for-profit
# 0             1  Princeton University    NJ  Private-not-for-profit
#
#    endowment-fy-begin  endowment-amount  ug-enrollment-year  \
# 4                2019       25900000000                2019
# 3                2020       26100000000                2020
# 2                2021       26200000000                2021
# 1                2022       37700000000                2022
# 0                2023       35800000000                2023
#
#    ug-enrolled-total  ug-first-time-enrolled  ug-first-time-admitted  \
# 4               5328              1,335.0000              1,895.0000
# ...

# %% [markdown]
# #### **Yale**

# %%
yale_df = clean_df[clean_df.university == 'Yale University'].sort_values(by=['endowment-fy-begin']).copy()

# %%
# adds column to calculate YoY difference of endowment
yale_df['end-yoy-diff'] = yale_df['endowment-amount'].diff()

# %%
# adds column to calculate YoY difference of ug-enrolled-total variable
yale_df['ug-enrtotal-yoy-diff'] = yale_df['ug-enrolled-total'].diff()

# %%
# adds column to calculate YoY difference of ug-first-time-enrolled variable
yale_df['ug-first-time-enr-yoy-diff'] = yale_df['ug-first-time-enrolled'].diff()

# %%
# adds column to calculate YoY difference of ug-first-time-admitted variable
yale_df['ug-first-time-adm-yoy-diff'] = yale_df['ug-first-time-admitted'].diff()

# %%
# adds column to calculate pct change of endowment-amount
yale_df['endowment-pct-chg'] = yale_df['endowment-amount'].pct_change()

# %%
# adds column to calculate pct change of ug-enrolled-total
yale_df['ugtotal-pct-chg'] = yale_df['ug-enrolled-total'].pct_change()

# %%
# adds column to calculate pct change of ug-first-time-enrolled
yale_df['ugfirst-time-pct-chg'] = yale_df['ug-first-time-enrolled'].pct_change()

# %%
# adds column to calculate pct change of ug-first-time-admitted
yale_df['ug-admitted-pct-chg'] = yale_df['ug-first-time-admitted'].pct_change()

# %%
yale_df
# Out:
#    ranking-2023       university state                    type  \
# 9             2  Yale University    CT  Private-not-for-profit
# 8             2  Yale University    CT  Private-not-for-profit
# 7             2  Yale University    CT  Private-not-for-profit
# 6             2  Yale University    CT  Private-not-for-profit
# 5             2  Yale University    CT  Private-not-for-profit
#
#    endowment-fy-begin  endowment-amount  ug-enrollment-year  \
# 9                2019       29351100000                2019
# 8                2020       30314800000                2020
# 7                2021       31201700000                2021
# 6                2022       42300000000                2022
# 5                2023       41400000000                2023
#
#    ug-enrolled-total  ug-first-time-enrolled  ug-first-time-admitted  \
# 9               6092              1,550.0000              2,241.0000
# 8               4703              1,264.0000              2,299.0000
# ...

# %% [markdown]
# #### **Stanford**

# %%
stanford_df = clean_df[clean_df.university == 'Stanford University'].sort_values(by=['endowment-fy-begin']).copy()

# %%
# adds column to calculate YoY difference of endowment
stanford_df['end-yoy-diff'] = stanford_df['endowment-amount'].diff()

# %%
# adds column to calculate YoY difference of ug-enrolled-total variable
stanford_df['ug-enrtotal-yoy-diff'] = stanford_df['ug-enrolled-total'].diff()

# %%
# adds column to calculate YoY difference of ug-first-time-enrolled variable
stanford_df['ug-first-time-enr-yoy-diff'] = stanford_df['ug-first-time-enrolled'].diff()

# %%
# adds column to calculate YoY difference of ug-first-time-admitted variable
stanford_df['ug-first-time-adm-yoy-diff'] = stanford_df['ug-first-time-admitted'].diff()

# %%
# adds column to calculate pct change of endowment-amount
stanford_df['endowment-pct-chg'] = stanford_df['endowment-amount'].pct_change()

# %%
# adds column to calculate pct change of ug-enrolled-total
stanford_df['ugtotal-pct-chg'] = stanford_df['ug-enrolled-total'].pct_change()

# %%
# adds column to calculate pct change of ug-first-time-enrolled
stanford_df['ugfirst-time-pct-chg'] = stanford_df['ug-first-time-enrolled'].pct_change()

# %%
# adds column to calculate pct change of ug-first-time-admitted
stanford_df['ug-admitted-pct-chg'] = stanford_df['ug-first-time-admitted'].pct_change()

# %%
stanford_df
# Out:
#     ranking-2023           university state                    type  \
# 14             3  Stanford University    CA  Private-not-for-profit
# 13             3  Stanford University    CA  Private-not-for-profit
# 12             3  Stanford University    CA  Private-not-for-profit
# 11             3  Stanford University    CA  Private-not-for-profit
# 10             3  Stanford University    CA  Private-not-for-profit
#
#     endowment-fy-begin  endowment-amount  ug-enrollment-year  \
# 14                2019       26500000000                2019
# 13                2020       27700000000                2020
# 12                2021       47200000000                2021
# 11                2022       37800000000                2022
# 10                2023       36300000000                2023
#
#     ug-enrolled-total  ug-first-time-enrolled  ug-first-time-admitted  \
# 14               6996              1,701.0000              2,062.0000
# ...

# %% [markdown]
# #### **MIT**

# %%
mit_df = clean_df[clean_df.university == 'Massachusetts Institute of Technology'].sort_values(by=['endowment-fy-begin']).copy()

# %%
# adds column to calculate YoY difference of endowment
mit_df['end-yoy-diff'] = mit_df['endowment-amount'].diff()

# %%
# adds column to calculate YoY difference of ug-enrolled-total variable
mit_df['ug-enrtotal-yoy-diff'] = mit_df['ug-enrolled-total'].diff()

# %%
# adds column to calculate YoY difference of ug-first-time-enrolled variable
mit_df['ug-first-time-enr-yoy-diff'] = mit_df['ug-first-time-enrolled'].diff()

# %%
# adds column to calculate YoY difference of ug-first-time-admitted variable
mit_df['ug-first-time-adm-yoy-diff'] = mit_df['ug-first-time-admitted'].diff()

# %%
# adds column to calculate pct change of endowment-amount
mit_df['endowment-pct-chg'] = mit_df['endowment-amount'].pct_change()

# %%
# adds column to calculate pct change of ug-enrolled-total
mit_df['ugtotal-pct-chg'] = mit_df['ug-enrolled-total'].pct_change()

# %%
# adds column to calculate pct change of ug-first-time-enrolled
mit_df['ugfirst-time-pct-chg'] = mit_df['ug-first-time-enrolled'].pct_change()

# %%
# adds column to calculate pct change of ug-first-time-admitted
mit_df['ug-admitted-pct-chg'] = mit_df['ug-first-time-admitted'].pct_change()

# %%
mit_df
# Out:
#     ranking-2023                             university state  \
# 19             4  Massachusetts Institute of Technology    MA
# 18             4  Massachusetts Institute of Technology    MA
# 17             4  Massachusetts Institute of Technology    MA
# 16             4  Massachusetts Institute of Technology    MA
# 15             4  Massachusetts Institute of Technology    MA
#
#                       type  endowment-fy-begin  endowment-amount  \
# 19  Private-not-for-profit                2019       16400000000
# 18  Private-not-for-profit                2020       17400000000
# 17  Private-not-for-profit                2021       18400000000
# 16  Private-not-for-profit                2022       27400000000
# 15  Private-not-for-profit                2023       24600000000
#
#     ug-enrollment-year  ug-enrolled-total  ug-first-time-enrolled  \
# 19                2019               4530              1,102.0000
# ...

# %% [markdown]
# #### **University of California, Berkeley**

# %%
ucb_df = clean_df[clean_df.university == 'University of California, Berkeley'].sort_values(by=['endowment-fy-begin']).copy()

# %%
# adds column to calculate YoY difference of endowment
ucb_df['end-yoy-diff'] = ucb_df['endowment-amount'].diff()

# %%
# adds column to calculate YoY difference of ug-enrolled-total variable
ucb_df['ug-enrtotal-yoy-diff'] = ucb_df['ug-enrolled-total'].diff()

# %%
# adds column to calculate YoY difference of ug-first-time-enrolled variable
ucb_df['ug-first-time-enr-yoy-diff'] = ucb_df['ug-first-time-enrolled'].diff()

# %%
# adds column to calculate YoY difference of ug-first-time-admitted variable
ucb_df['ug-first-time-adm-yoy-diff'] = ucb_df['ug-first-time-admitted'].diff()

# %%
# adds column to calculate pct change of endowment-amount
ucb_df['endowment-pct-chg'] = ucb_df['endowment-amount'].pct_change()

# %%
# adds column to calculate pct change of ug-enrolled-total
ucb_df['ugtotal-pct-chg'] = ucb_df['ug-enrolled-total'].pct_change()

# %%
# adds column to calculate pct change of ug-first-time-enrolled
ucb_df['ugfirst-time-pct-chg'] = ucb_df['ug-first-time-enrolled'].pct_change()

# %%
# adds column to calculate pct change of ug-first-time-admitted
ucb_df['ug-admitted-pct-chg'] = ucb_df['ug-first-time-admitted'].pct_change()

# %%
ucb_df
# Out:
#     ranking-2023                          university state    type  \
# 24             5  University of California, Berkeley    CA  Public
# 23             5  University of California, Berkeley    CA  Public
# 22             5  University of California, Berkeley    CA  Public
# 21             5  University of California, Berkeley    CA  Public
# 20             5  University of California, Berkeley    CA  Public
#
#     endowment-fy-begin  endowment-amount  ug-enrollment-year  \
# 24                2019       20700000000                2019
# 23                2020       21200000000                2020
# 22                2021       29200000000                2021
# 21                2022       26500000000                2022
# 20                2023       29000000000                2023
#
#     ug-enrolled-total  ug-first-time-enrolled  ug-first-time-admitted  \
# 24              31348              6,465.0000             14,336.0000
# ...

# %% [markdown]
# #### **University of California, Los Angeles**

# %%
ucla_df = clean_df[clean_df.university == 'University of California, Los Angeles'].sort_values(by=['endowment-fy-begin']).copy()

# %%
# adds column to calculate YoY difference of endowment
ucla_df['end-yoy-diff'] = ucla_df['endowment-amount'].diff()

# %%
# adds column to calculate YoY difference of ug-enrolled-total variable
ucla_df['ug-enrtotal-yoy-diff'] = ucla_df['ug-enrolled-total'].diff()

# %%
# adds column to calculate YoY difference of ug-first-time-enrolled variable
ucla_df['ug-first-time-enr-yoy-diff'] = ucla_df['ug-first-time-enrolled'].diff()

# %%
# adds column to calculate YoY difference of ug-first-time-admitted variable
ucla_df['ug-first-time-adm-yoy-diff'] = ucla_df['ug-first-time-admitted'].diff()

# %%
# adds column to calculate pct change of endowment-amount
ucla_df['endowment-pct-chg'] = ucla_df['endowment-amount'].pct_change()

# %%
# adds column to calculate pct change of ug-enrolled-total
ucla_df['ugtotal-pct-chg'] = ucla_df['ug-enrolled-total'].pct_change()

# %%
# adds column to calculate pct change of ug-first-time-enrolled
ucla_df['ugfirst-time-pct-chg'] = ucla_df['ug-first-time-enrolled'].pct_change()

# %%
# adds column to calculate pct change of ug-first-time-admitted
ucla_df['ug-admitted-pct-chg'] = ucla_df['ug-first-time-admitted'].pct_change()

# %%
ucla_df
# Out:
#     ranking-2023                             university state    type  \
# 34             7  University of California, Los Angeles    CA  Public
# 33             7  University of California, Los Angeles    CA  Public
# 32             7  University of California, Los Angeles    CA  Public
# 31             7  University of California, Los Angeles    CA  Public
# 30             7  University of California, Los Angeles    CA  Public
#
#     endowment-fy-begin  endowment-amount  ug-enrollment-year  \
# 34                2019        3800000000                2019
# 33                2020        4000000000                2020
# 32                2021        5100000000                2021
# 31                2022        5000000000                2022
# 30                2023        5500000000                2023
#
#     ug-enrolled-total  ug-first-time-enrolled  ug-first-time-admitted  \
# 34              31543              5,920.0000             13,432.0000
# ...

# %% [markdown]
# #### **University of Pennsylvania**

# %%
upenn_df = clean_df[clean_df.university == 'University of Pennsylvania'].sort_values(by=['endowment-fy-begin']).copy()

# %%
# adds column to calculate YoY difference of endowment
upenn_df['end-yoy-diff'] = upenn_df['endowment-amount'].diff()

# %%
# adds column to calculate YoY difference of ug-enrolled-total variable
upenn_df['ug-enrtotal-yoy-diff'] = upenn_df['ug-enrolled-total'].diff()

# %%
# adds column to calculate YoY difference of ug-first-time-enrolled variable
upenn_df['ug-first-time-enr-yoy-diff'] = upenn_df['ug-first-time-enrolled'].diff()

# %%
# adds column to calculate YoY difference of ug-first-time-admitted variable
upenn_df['ug-first-time-adm-yoy-diff'] = upenn_df['ug-first-time-admitted'].diff()

# %%
# adds column to calculate pct change of endowment-amount
upenn_df['endowment-pct-chg'] = upenn_df['endowment-amount'].pct_change()

# %%
# adds column to calculate pct change of ug-enrolled-total
upenn_df['ugtotal-pct-chg'] = upenn_df['ug-enrolled-total'].pct_change()

# %%
# adds column to calculate pct change of ug-first-time-enrolled
upenn_df['ugfirst-time-pct-chg'] = upenn_df['ug-first-time-enrolled'].pct_change()

# %%
# adds column to calculate pct change of ug-first-time-admitted
upenn_df['ug-admitted-pct-chg'] = upenn_df['ug-first-time-admitted'].pct_change()

# %%
upenn_df
# Out:
#     ranking-2023                  university state                    type  \
# 39             8  University of Pennsylvania    PA  Private not-for-profit
# 38             8  University of Pennsylvania    PA  Private not-for-profit
# 37             8  University of Pennsylvania    PA  Private not-for-profit
# 36             8  University of Pennsylvania    PA  Private not-for-profit
# 35             8  University of Pennsylvania    PA  Private not-for-profit
#
#     endowment-fy-begin  endowment-amount  ug-enrollment-year  \
# 39                2019       14700000000                2019
# 38                2020       14900000000                2020
# 37                2021       20500000000                2021
# 36                2022       20700000000                2022
# 35                2023       21000000000                2023
#
#     ug-enrolled-total  ug-first-time-enrolled  ug-first-time-admitted  \
# 39              10019              2,340.0000              3,446.0000
# ...

# %% [markdown]
# #### **Harvard University**

# %%
harvard_df = clean_df[clean_df.university == 'Harvard University'].sort_values(by=['endowment-fy-begin']).copy()

# %%
# adds column to calculate YoY difference of endowment
harvard_df['end-yoy-diff'] = harvard_df['endowment-amount'].diff()

# %%
# adds column to calculate YoY difference of ug-enrolled-total variable
harvard_df['ug-enrtotal-yoy-diff'] = harvard_df['ug-enrolled-total'].diff()

# %%
# adds column to calculate YoY difference of ug-first-time-enrolled variable
harvard_df['ug-first-time-enr-yoy-diff'] = harvard_df['ug-first-time-enrolled'].diff()

# %%
# adds column to calculate YoY difference of ug-first-time-admitted variable
harvard_df['ug-first-time-adm-yoy-diff'] = harvard_df['ug-first-time-admitted'].diff()

# %%
# adds column to calculate pct change of endowment-amount
harvard_df['endowment-pct-chg'] = harvard_df['endowment-amount'].pct_change()

# %%
# adds column to calculate pct change of ug-enrolled-total
harvard_df['ugtotal-pct-chg'] = harvard_df['ug-enrolled-total'].pct_change()

# %%
# adds column to calculate pct change of ug-first-time-enrolled
harvard_df['ugfirst-time-pct-chg'] = harvard_df['ug-first-time-enrolled'].pct_change()

# %%
# adds column to calculate pct change of ug-first-time-admitted
harvard_df['ug-admitted-pct-chg'] = harvard_df['ug-first-time-admitted'].pct_change()

# %%
harvard_df
# Out:
#     ranking-2023          university state                    type  \
# 44             9  Harvard University    MA  Private not-for-profit
# 43             9  Harvard University    MA  Private not-for-profit
# 42             9  Harvard University    MA  Private not-for-profit
# 41             9  Harvard University    MA  Private not-for-profit
# 40             9  Harvard University    MA  Private not-for-profit
#
#     endowment-fy-begin  endowment-amount  ug-enrollment-year  \
# 44                2019       40900000000                2019
# 43                2020       41900000000                2020
# 42                2021       53200000000                2021
# 41                2022       50900000000                2022
# 40                2023       50700000000                2023
#
#     ug-enrolled-total  ug-first-time-enrolled  ug-first-time-admitted  \
# 44               6755              1,644.0000              2,009.0000
# ...

# %% [markdown]
# #### **Williams College**

# %%
williams_df = clean_df[clean_df.university == 'Williams College'].sort_values(by=['endowment-fy-begin']).copy()

# %%
# adds column to calculate YoY difference of endowment
williams_df['end-yoy-diff'] = williams_df['endowment-amount'].diff()

# %%
# adds column to calculate YoY difference of ug-enrolled-total variable
williams_df['ug-enrtotal-yoy-diff'] = williams_df['ug-enrolled-total'].diff()

# %%
# adds column to calculate YoY difference of ug-first-time-enrolled variable
williams_df['ug-first-time-enr-yoy-diff'] = williams_df['ug-first-time-enrolled'].diff()

# %%
# adds column to calculate YoY difference of ug-first-time-admitted variable
williams_df['ug-first-time-adm-yoy-diff'] = williams_df['ug-first-time-admitted'].diff()

# %%
# adds column to calculate pct change of endowment-amount
williams_df['endowment-pct-chg'] = williams_df['endowment-amount'].pct_change()

# %%
# adds column to calculate pct change of ug-enrolled-total
williams_df['ugtotal-pct-chg'] = williams_df['ug-enrolled-total'].pct_change()

# %%
# adds column to calculate pct change of ug-first-time-enrolled
williams_df['ugfirst-time-pct-chg'] = williams_df['ug-first-time-enrolled'].pct_change()

# %%
# adds column to calculate pct change of ug-first-time-admitted
williams_df['ug-admitted-pct-chg'] = williams_df['ug-first-time-admitted'].pct_change()

# %%
williams_df
# Out:
#     ranking-2023        university state                    type  \
# 49            10  Williams College    MA  Private not-for-profit
# 48            10  Williams College    MA  Private not-for-profit
# 47            10  Williams College    MA  Private not-for-profit
# 46            10  Williams College    MA  Private not-for-profit
# 45            10  Williams College    MA  Private not-for-profit
#
#     endowment-fy-begin  endowment-amount  ug-enrollment-year  \
# 49                2019        2900000000                2019
# 48                2020        2800000000                2020
# 47                2021        4200000000                2021
# 46                2022        3500000000                2022
# 45                2023        3500000000                2023
#
#     ug-enrolled-total  ug-first-time-enrolled  ug-first-time-admitted  \
# 49               2078                546.0000              1,224.0000
# ...

# %% [markdown]
# #### **Amherst College**

# %%
amherst_df = clean_df[clean_df.university == 'Amherst College'].sort_values(by=['endowment-fy-begin']).copy()

# %%
amherst_df['end-yoy-diff'] = amherst_df['endowment-amount'].diff()

# %%
# adds column to calculate YoY difference of ug-enrolled-total variable
amherst_df['ug-enrtotal-yoy-diff'] = amherst_df['ug-enrolled-total'].diff()

# %%
# adds column to calculate YoY difference of ug-first-time-enrolled variable
amherst_df['ug-first-time-enr-yoy-diff'] = amherst_df['ug-first-time-enrolled'].diff()

# %%
# adds column to calculate YoY difference of ug-first-time-admitted variable
amherst_df['ug-first-time-adm-yoy-diff'] = amherst_df['ug-first-time-admitted'].diff()

# %%
# adds column to calculate pct change of endowment-amount
amherst_df['endowment-pct-chg'] = amherst_df['endowment-amount'].pct_change()

# %%
# adds column to calculate pct change of ug-enrolled-total
amherst_df['ugtotal-pct-chg'] = amherst_df['ug-enrolled-total'].pct_change()

# %%
# adds column to calculate pct change of ug-first-time-enrolled
amherst_df['ugfirst-time-pct-chg'] = amherst_df['ug-first-time-enrolled'].pct_change()

# %%
# adds column to calculate pct change of ug-first-time-admitted
amherst_df['ug-admitted-pct-chg'] = amherst_df['ug-first-time-admitted'].pct_change()

# %%
amherst_df
# Out:
#     ranking-2023       university state                    type  \
# 54            11  Amherst College    MA  Private not-for-profit
# 53            11  Amherst College    MA  Private not-for-profit
# 52            11  Amherst College    MA  Private not-for-profit
# 51            11  Amherst College    MA  Private not-for-profit
# 50            11  Amherst College    MA  Private not-for-profit
#
#     endowment-fy-begin  endowment-amount  ug-enrollment-year  \
# 54                2019        2473000000                2019
# 53                2020        3150000000                2020
# 52                2021        4630000000                2021
# 51                2022        4040000000                2022
# 50                2023        4060000000                2023
#
#     ug-enrolled-total  ug-first-time-enrolled  ug-first-time-admitted  \
# 54               1839                470.0000              1,195.0000
# ...

# %% [markdown]
# # **Merging Needed Columns**
# - Creating truncated versions of each university/college dataframe, w/ only addl. columns created
# - Merging 4 created columns with clean_df, on indices

# %%
# creating truncated Princeton U. dataframe w/ only created columns
princeton_trunc_df = princeton_df[['end-yoy-diff', 'ug-enrtotal-yoy-diff', 'ug-first-time-enr-yoy-diff', 'ug-first-time-adm-yoy-diff', \
                                   'endowment-pct-chg', 'ugtotal-pct-chg', 'ugfirst-time-pct-chg', 'ug-admitted-pct-chg']].copy()

# %%
# creating truncated Yale U. dataframe w/ only created columns
yale_trunc_df = yale_df[['end-yoy-diff', 'ug-enrtotal-yoy-diff', 'ug-first-time-enr-yoy-diff', 'ug-first-time-adm-yoy-diff', \
                        'endowment-pct-chg', 'ugtotal-pct-chg', 'ugfirst-time-pct-chg', 'ug-admitted-pct-chg']].copy()

# %%
# creating truncated Stanford U. dataframe w/ only created columns
stan_trunc_df = stanford_df[['end-yoy-diff', 'ug-enrtotal-yoy-diff', 'ug-first-time-enr-yoy-diff', 'ug-first-time-adm-yoy-diff', \
                             'endowment-pct-chg', 'ugtotal-pct-chg', 'ugfirst-time-pct-chg', 'ug-admitted-pct-chg']].copy()

# %%
# creating truncated MIT dataframe w/ only created columns
mit_trunc_df = mit_df[['end-yoy-diff', 'ug-enrtotal-yoy-diff', 'ug-first-time-enr-yoy-diff', 'ug-first-time-adm-yoy-diff', \
                       'endowment-pct-chg', 'ugtotal-pct-chg', 'ugfirst-time-pct-chg', 'ug-admitted-pct-chg']].copy()

# %%
# creating truncated UCB dataframe w/ only created columns
ucb_trunc_df = ucb_df[['end-yoy-diff', 'ug-enrtotal-yoy-diff', 'ug-first-time-enr-yoy-diff', 'ug-first-time-adm-yoy-diff', \
                       'endowment-pct-chg', 'ugtotal-pct-chg', 'ugfirst-time-pct-chg', 'ug-admitted-pct-chg']].copy()

# %%
# creating truncated UCLA dataframe w/ only created columns
ucla_trunc_df = ucla_df[['end-yoy-diff', 'ug-enrtotal-yoy-diff', 'ug-first-time-enr-yoy-diff', 'ug-first-time-adm-yoy-diff', \
                         'endowment-pct-chg', 'ugtotal-pct-chg', 'ugfirst-time-pct-chg', 'ug-admitted-pct-chg']].copy()

# %%
# creating truncated UPenn dataframe w/ only created columns
upenn_trunc_df = upenn_df[['end-yoy-diff', 'ug-enrtotal-yoy-diff', 'ug-first-time-enr-yoy-diff', 'ug-first-time-adm-yoy-diff', \
                           'endowment-pct-chg', 'ugtotal-pct-chg', 'ugfirst-time-pct-chg', 'ug-admitted-pct-chg']].copy()

# %%
# creating truncated Harvard U. dataframe w/ only created columns
harvard_trunc_df = harvard_df[['end-yoy-diff', 'ug-enrtotal-yoy-diff', 'ug-first-time-enr-yoy-diff', 'ug-first-time-adm-yoy-diff', \
                               'endowment-pct-chg', 'ugtotal-pct-chg', 'ugfirst-time-pct-chg', 'ug-admitted-pct-chg']].copy()

# %%
# creating truncated Williams College dataframe w/ only created columns
williams_trunc_df = williams_df[['end-yoy-diff', 'ug-enrtotal-yoy-diff', 'ug-first-time-enr-yoy-diff', 'ug-first-time-adm-yoy-diff', \
                                 'endowment-pct-chg', 'ugtotal-pct-chg', 'ugfirst-time-pct-chg', 'ug-admitted-pct-chg']].copy()

# %%
# creating truncated Amherst College dataframe w/ only created columns
amherst_trunc_df = amherst_df[['end-yoy-diff', 'ug-enrtotal-yoy-diff', 'ug-first-time-enr-yoy-diff', 'ug-first-time-adm-yoy-diff', \
                               'endowment-pct-chg', 'ugtotal-pct-chg', 'ugfirst-time-pct-chg', 'ug-admitted-pct-chg']].copy()

# %%
# list of truncated dataframes
trunc_list = [princeton_trunc_df, yale_trunc_df, stan_trunc_df, mit_trunc_df, ucb_trunc_df, ucla_trunc_df, upenn_trunc_df, \
              harvard_trunc_df, williams_trunc_df, amherst_trunc_df]

# %%
# dataframe created out of truncated dataframes compilation
tomerge_df = pd.concat(trunc_list)

# %%
tomerge_df.head()
# Out:
#          end-yoy-diff  ug-enrtotal-yoy-diff  ug-first-time-enr-yoy-diff  \
# 4                 NaN                   NaN                         NaN
# 3    200,000,000.0000             -640.0000                   -189.0000
# 2    100,000,000.0000              552.0000                    142.0000
# 1 11,500,000,000.0000              300.0000                    209.0000
# 0 -1,900,000,000.0000               58.0000                   -131.0000
#
#    ug-first-time-adm-yoy-diff  endowment-pct-chg  ugtotal-pct-chg  \
# 4                         NaN                NaN              NaN
# 3                    -47.0000             0.0077          -0.1201
# 2                   -201.0000             0.0038           0.1177
# 1                    520.0000             0.4389           0.0573
# 0                   -385.0000            -0.0504           0.0105
#
#    ugfirst-time-pct-chg  ug-admitted-pct-chg
# 4                   NaN                  NaN
# ...

# %%
# merging created columns with clean_df
merged_df = clean_df.merge(tomerge_df, left_on = clean_df.index, right_on = tomerge_df.index)

# %%
# validating post-merge. expecting same number of rows, & 5 addl. columns in merged_df
print(f'Cleaned Shape: {clean_df.shape}')
print(f'Merged Shape: {merged_df.shape}')
# Out:
# Cleaned Shape: (50, 10)
# Merged Shape: (50, 19)

# %%
# removing added column for index during merge (key_0)
merged_df = merged_df[['ranking-2023', 'university', 'state', 'type', 'endowment-fy-begin',
       'endowment-amount', 'ug-enrollment-year', 'ug-enrolled-total',
       'ug-first-time-enrolled', 'ug-first-time-admitted', 'end-yoy-diff',
       'ug-enrtotal-yoy-diff', 'ug-first-time-enr-yoy-diff',
       'ug-first-time-adm-yoy-diff', 'endowment-pct-chg', 'ugtotal-pct-chg', 'ugfirst-time-pct-chg', 'ug-admitted-pct-chg']]

# %%
merged_df.head()
# Out:
#    ranking-2023            university state                    type  \
# 0             1  Princeton University    NJ  Private-not-for-profit
# 1             1  Princeton University    NJ  Private-not-for-profit
# 2             1  Princeton University    NJ  Private-not-for-profit
# 3             1  Princeton University    NJ  Private-not-for-profit
# 4             1  Princeton University    NJ  Private-not-for-profit
#
#    endowment-fy-begin  endowment-amount  ug-enrollment-year  \
# 0                2023       35800000000                2023
# 1                2022       37700000000                2022
# 2                2021       26200000000                2021
# 3                2020       26100000000                2020
# 4                2019       25900000000                2019
#
#    ug-enrolled-total  ug-first-time-enrolled  ug-first-time-admitted  \
# 0               5598              1,366.0000              1,782.0000
# ...

# %% [markdown]
# # **Rates of Total Endowment by University**
# - All graphs' x-axis label indicates the total endowment amount that the University would have begun the same year's Fall Undergraduate class with.

# %% [markdown]
# #### Princeton University

# %%
# creating line graph for change in total endowment YoY
fig, ax = plt.subplots(figsize=(8,4))
princeton_endowment_chg = sns.lineplot(data=princeton_df, x='endowment-fy-begin', y='endowment-amount')

# setting x-axis ticks to endowment years
princeton_endowment_chg.set_xticks(princeton_df['endowment-fy-begin'])

# setting axis labels
ax.set_xlabel('Starting Endowment Amount for fall UG year')
ax.set_ylabel('Total Endowment (in billions)')

# setting plot title
plt.title('Princeton Change in Total Endowment 2019-2023')

# graph augments
#plt.ticklabel_format(style='plain', axis='y')
sns.despine()
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### Yale University

# %%
# creating line graph for change in total endowment YoY
fig, ax = plt.subplots(figsize=(8,4))
yale_endowment_chg = sns.lineplot(data=yale_df, x='endowment-fy-begin', y='endowment-amount')

# setting x-axis ticks to endowment years
yale_endowment_chg.set_xticks(yale_df['endowment-fy-begin'])
# setting axis labels
ax.set_xlabel('Starting Endowment Amount for fall UG year')
ax.set_ylabel('Total Endowment (in billions)')
# setting plot title
plt.title('Yale Change in Total Endowment 2019-2023')
# graph augments
#plt.ticklabel_format(style='plain', axis='y')
sns.despine()
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### Stanford University

# %%
# creating line graph for change in total endowment YoY
fig, ax = plt.subplots(figsize=(8,4))
stanford_endowment_chg = sns.lineplot(data=stanford_df, x='endowment-fy-begin', y='endowment-amount')

# setting x-axis ticks to endowment years
stanford_endowment_chg.set_xticks(stanford_df['endowment-fy-begin'])
# setting axis labels
ax.set_xlabel('Starting Endowment Amount for fall UG year')
ax.set_ylabel('Total Endowment (in billions)')
# setting plot title
plt.title('Stanford Change in Total Endowment 2019-2023')
# graph augments
#plt.ticklabel_format(style='plain', axis='y')
sns.despine()
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### MIT

# %%
# creating line graph for change in total endowment YoY
fig, ax = plt.subplots(figsize=(8,4))
mit_endowment_chg = sns.lineplot(data=mit_df, x='endowment-fy-begin', y='endowment-amount')

# setting x-axis ticks to endowment years
mit_endowment_chg.set_xticks(mit_df['endowment-fy-begin'])
# setting axis labels
ax.set_xlabel('Starting Endowment Amount for fall UG year')
ax.set_ylabel('Total Endowment (in billions)')
# setting plot title
plt.title('MIT Change in Total Endowment 2019-2023')
# graph augments
#plt.ticklabel_format(style='plain', axis='y')
sns.despine()
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### University of California, Berkeley

# %%
# creating line graph for change in total endowment YoY
fig, ax = plt.subplots(figsize=(8,4))
ucb_endowment_chg = sns.lineplot(data=ucb_df, x='endowment-fy-begin', y='endowment-amount')

# setting x-axis ticks to endowment years
ucb_endowment_chg.set_xticks(ucb_df['endowment-fy-begin'])
# setting axis labels
ax.set_xlabel('Starting Endowment Amount for fall UG year')
ax.set_ylabel('Total Endowment (in billions)')
# setting plot title
plt.title('UCB Change in Total Endowment 2019-2023')
# graph augments
#plt.ticklabel_format(style='plain', axis='y')
sns.despine()
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### University of California, Los Angeles

# %%
# creating line graph for change in total endowment YoY
fig, ax = plt.subplots(figsize=(8,4))
ucla_endowment_chg = sns.lineplot(data=ucla_df, x='endowment-fy-begin', y='endowment-amount')

# setting x-axis ticks to endowment years
ucla_endowment_chg.set_xticks(ucla_df['endowment-fy-begin'])
# setting axis labels
ax.set_xlabel('Starting Endowment Amount for fall UG year')
ax.set_ylabel('Total Endowment (in billions)')
# setting plot title
plt.title('UCLA Change in Total Endowment 2019-2023')
# graph augments
#plt.ticklabel_format(style='plain', axis='y')
sns.despine()
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### University of Pennsylvania

# %%
# creating line graph for change in total endowment YoY
fig, ax = plt.subplots(figsize=(8,4))
upenn_endowment_chg = sns.lineplot(data=upenn_df, x='endowment-fy-begin', y='endowment-amount')

# setting x-axis ticks to endowment years
upenn_endowment_chg.set_xticks(upenn_df['endowment-fy-begin'])
# setting axis labels
ax.set_xlabel('Starting Endowment Amount for fall UG year')
ax.set_ylabel('Total Endowment (in billions)')
# setting plot title
plt.title('UPenn Change in Total Endowment 2019-2023')
# graph augments
#plt.ticklabel_format(style='plain', axis='y')
sns.despine()
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### Harvard University

# %%
# creating line graph for change in total endowment YoY
fig, ax = plt.subplots(figsize=(8,4))
harvard_endowment_chg = sns.lineplot(data=harvard_df, x='endowment-fy-begin', y='endowment-amount')

# setting x-axis ticks to endowment years
harvard_endowment_chg.set_xticks(harvard_df['endowment-fy-begin'])
# setting axis labels
ax.set_xlabel('Starting Endowment Amount for fall UG year')
ax.set_ylabel('Total Endowment (in billions)')
# setting plot title
plt.title('Harvard Change in Total Endowment 2019-2023')
# graph augments
#plt.ticklabel_format(style='plain', axis='y')
sns.despine()
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### Williams College

# %%
# creating line graph for change in total endowment YoY
fig, ax = plt.subplots(figsize=(8,4))
williams_endowment_chg = sns.lineplot(data=williams_df, x='endowment-fy-begin', y='endowment-amount')

# setting x-axis ticks to endowment years
williams_endowment_chg.set_xticks(williams_df['endowment-fy-begin'])
# setting axis labels
ax.set_xlabel('Starting Endowment Amount for fall UG year')
ax.set_ylabel('Total Endowment (in billions)')
# setting plot title
plt.title('Williams Change in Total Endowment 2019-2023')
# graph augments
#plt.ticklabel_format(style='plain', axis='y')
sns.despine()
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### Amherst College

# %%
# creating line graph for change in total endowment YoY
fig, ax = plt.subplots(figsize=(8,4))
amherst_endowment_chg = sns.lineplot(data=amherst_df, x='endowment-fy-begin', y='endowment-amount')

# setting x-axis ticks to endowment years
amherst_endowment_chg.set_xticks(amherst_df['endowment-fy-begin'])
# setting axis labels
ax.set_xlabel('Starting Endowment Amount for fall UG year')
ax.set_ylabel('Total Endowment (in billions)')
# setting plot title
plt.title('Amherst Change in Total Endowment 2019-2023')
# graph augments
#plt.ticklabel_format(style='plain', axis='y')
sns.despine()
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # **Total Endowment vs. Total Enrollment by University**

# %% [markdown]
# ### 1) Princeton

# %%
# creating dataframe with only total endowment & total enrollment percentage changes
princeton_end_enr = princeton_df[['endowment-fy-begin', 'endowment-pct-chg', 'ugtotal-pct-chg']]

# %%
# removing year 2019 due to all 0 values
princeton_end_enr = princeton_end_enr.query('`endowment-fy-begin` != 2019').copy()
princeton_end_enr
# Out:
#    endowment-fy-begin  endowment-pct-chg  ugtotal-pct-chg
# 3                2020             0.0077          -0.1201
# 2                2021             0.0038           0.1177
# 1                2022             0.4389           0.0573
# 0                2023            -0.0504           0.0105

# %%
# converting total endowment and total enrollment to long data for multiline plot
princeton_end_enr_long = princeton_end_enr.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ugtotal-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
princeton_end_enr_long = princeton_end_enr_long.assign(Type=princeton_end_enr_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ugtotal-pct-chg' : 'Enrollment'}))

# %%
# sort by year (endowment-fy-begin) ASC
princeton_end_enr_long = princeton_end_enr_long.sort_values(by=['endowment-fy-begin'])
princeton_end_enr_long
# Out:
#    endowment-fy-begin               type  percentage        Type
# 0                2020  endowment-pct-chg      0.0077   Endowment
# 4                2020    ugtotal-pct-chg     -0.1201  Enrollment
# 1                2021  endowment-pct-chg      0.0038   Endowment
# 5                2021    ugtotal-pct-chg      0.1177  Enrollment
# 2                2022  endowment-pct-chg      0.4389   Endowment
# 6                2022    ugtotal-pct-chg      0.0573  Enrollment
# 3                2023  endowment-pct-chg     -0.0504   Endowment
# 7                2023    ugtotal-pct-chg      0.0105  Enrollment

# %%
# creating dataframe for endowment coordinates
princeton_end_coord = princeton_end_enr_long[(princeton_end_enr_long.Type == 'Endowment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
princeton_end_coord['percentage'] = princeton_end_coord['percentage'].apply(lambda x: round(x, 4))
princeton_end_coord
# Out:
#    endowment-fy-begin  percentage
# 0                2020      0.0077
# 1                2021      0.0038
# 2                2022      0.4389
# 3                2023     -0.0504

# %%
# creating dataframe for enrollment coordinates
princeton_enr_coord = princeton_end_enr_long[(princeton_end_enr_long.Type == 'Enrollment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
princeton_enr_coord['percentage'] = princeton_enr_coord['percentage'].apply(lambda x: round(x, 4))
princeton_enr_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020     -0.1201
# 5                2021      0.1177
# 6                2022      0.0573
# 7                2023      0.0105

# %%
# plotting total enrollment and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
princeton_end_enr_plot = sns.lineplot(princeton_end_enr_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(princeton_end_enr_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points
for i, point in princeton_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"], str(point["percentage"]))

# annotate enrollment points
for i, point in princeton_enr_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.039, str(point["percentage"]))


ax.set_title('2020-2023 Princeton Endowment vs. Enrollment YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ### 2) Yale

# %%
# creating dataframe with only total endowment & total enrollment percentage changes
yale_end_enr = yale_df[['endowment-fy-begin', 'endowment-pct-chg', 'ugtotal-pct-chg']]

# %%
# removing year 2019 due to all 0 values
yale_end_enr = yale_end_enr.query('`endowment-fy-begin` != 2019').copy()
yale_end_enr
# Out:
#    endowment-fy-begin  endowment-pct-chg  ugtotal-pct-chg
# 8                2020             0.0328          -0.2280
# 7                2021             0.0293           0.3898
# 6                2022             0.3557           0.0167
# 5                2023            -0.0213           0.0260

# %%
# converting total endowment and total enrollment to long data for multiline plot
yale_end_enr_long = yale_end_enr.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ugtotal-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
yale_end_enr_long = yale_end_enr_long.assign(Type=yale_end_enr_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ugtotal-pct-chg' : 'Enrollment'}))

# %%
# sort by year (endowment-fy-begin) ASC
yale_end_enr_long = yale_end_enr_long.sort_values(by=['endowment-fy-begin'])
yale_end_enr_long
# Out:
#    endowment-fy-begin               type  percentage        Type
# 0                2020  endowment-pct-chg      0.0328   Endowment
# 4                2020    ugtotal-pct-chg     -0.2280  Enrollment
# 1                2021  endowment-pct-chg      0.0293   Endowment
# 5                2021    ugtotal-pct-chg      0.3898  Enrollment
# 2                2022  endowment-pct-chg      0.3557   Endowment
# 6                2022    ugtotal-pct-chg      0.0167  Enrollment
# 3                2023  endowment-pct-chg     -0.0213   Endowment
# 7                2023    ugtotal-pct-chg      0.0260  Enrollment

# %%
# creating dataframe for endowment coordinates
yale_end_coord = yale_end_enr_long[(yale_end_enr_long.Type == 'Endowment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
yale_end_coord['percentage'] = yale_end_coord['percentage'].apply(lambda x: round(x, 4))
yale_end_coord
# Out:
#    endowment-fy-begin  percentage
# 0                2020      0.0328
# 1                2021      0.0293
# 2                2022      0.3557
# 3                2023     -0.0213

# %%
# creating dataframe for enrollment coordinates
yale_enr_coord = yale_end_enr_long[(yale_end_enr_long.Type == 'Enrollment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
yale_enr_coord['percentage'] = yale_enr_coord['percentage'].apply(lambda x: round(x, 4))
yale_enr_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020     -0.2280
# 5                2021      0.3898
# 6                2022      0.0167
# 7                2023      0.0260

# %%
# plotting total enrollment and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
yale_end_enr_plot = sns.lineplot(yale_end_enr_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(yale_end_enr_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points
for i, point in yale_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.1, str(point["percentage"]))

# annotate enrollment points
for i, point in yale_enr_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"], str(point["percentage"]))


ax.set_title('2020-2023 Yale Endowment vs. Enrollment YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ### 3) Stanford

# %%
# creating dataframe with only total endowment & total enrollment percentage changes
stanford_end_enr = stanford_df[['endowment-fy-begin', 'endowment-pct-chg', 'ugtotal-pct-chg']]

# %%
# removing year 2019 due to all 0 values
stanford_end_enr = stanford_end_enr.query('`endowment-fy-begin` != 2019').copy()
stanford_end_enr
# Out:
#     endowment-fy-begin  endowment-pct-chg  ugtotal-pct-chg
# 13                2020             0.0453          -0.0901
# 12                2021             0.7040           0.2009
# 11                2022            -0.1992           0.0528
# 10                2023            -0.0397           0.0006

# %%
# converting total endowment and total enrollment to long data for multiline plot
stanford_end_enr_long = stanford_end_enr.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ugtotal-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
stanford_end_enr_long = stanford_end_enr_long.assign(Type=stanford_end_enr_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ugtotal-pct-chg' : 'Enrollment'}))

# %%
# sort by year (endowment-fy-begin) ASC
stanford_end_enr_long = stanford_end_enr_long.sort_values(by=['endowment-fy-begin'])
stanford_end_enr_long
# Out:
#    endowment-fy-begin               type  percentage        Type
# 0                2020  endowment-pct-chg      0.0453   Endowment
# 4                2020    ugtotal-pct-chg     -0.0901  Enrollment
# 1                2021  endowment-pct-chg      0.7040   Endowment
# 5                2021    ugtotal-pct-chg      0.2009  Enrollment
# 2                2022  endowment-pct-chg     -0.1992   Endowment
# 6                2022    ugtotal-pct-chg      0.0528  Enrollment
# 3                2023  endowment-pct-chg     -0.0397   Endowment
# 7                2023    ugtotal-pct-chg      0.0006  Enrollment

# %%
# creating dataframe for endowment coordinates
stanford_end_coord = stanford_end_enr_long[(stanford_end_enr_long.Type == 'Endowment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
stanford_end_coord['percentage'] = stanford_end_coord['percentage'].apply(lambda x: round(x, 4))
stanford_end_coord
# Out:
#    endowment-fy-begin  percentage
# 0                2020      0.0453
# 1                2021      0.7040
# 2                2022     -0.1992
# 3                2023     -0.0397

# %%
# creating dataframe for enrollment coordinates
stanford_enr_coord = stanford_end_enr_long[(stanford_end_enr_long.Type == 'Enrollment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
stanford_enr_coord['percentage'] = stanford_enr_coord['percentage'].apply(lambda x: round(x, 4))
stanford_enr_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020     -0.0901
# 5                2021      0.2009
# 6                2022      0.0528
# 7                2023      0.0006

# %%
# plotting total enrollment and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
stanford_end_enr_plot = sns.lineplot(stanford_end_enr_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(stanford_end_enr_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points
for i, point in stanford_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.01, str(point["percentage"]))

# annotate enrollment points
for i, point in stanford_enr_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.07, str(point["percentage"]))


ax.set_title('2020-2023 Stanford Endowment vs. Enrollment YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ### 4) MIT

# %%
# creating dataframe with only total endowment & total enrollment percentage changes
mit_end_enr = mit_df[['endowment-fy-begin', 'endowment-pct-chg', 'ugtotal-pct-chg']]

# %%
# removing year 2019 due to all 0 values
mit_end_enr = mit_end_enr.query('`endowment-fy-begin` != 2019').copy()
mit_end_enr
# Out:
#     endowment-fy-begin  endowment-pct-chg  ugtotal-pct-chg
# 18                2020             0.0610          -0.0373
# 17                2021             0.0575           0.0635
# 16                2022             0.4891           0.0041
# 15                2023            -0.1022          -0.0174

# %%
# converting total endowment and total enrollment to long data for multiline plot
mit_end_enr_long = mit_end_enr.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ugtotal-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
mit_end_enr_long = mit_end_enr_long.assign(Type=mit_end_enr_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ugtotal-pct-chg' : 'Enrollment'}))

# %%
# sort by year (endowment-fy-begin) ASC
mit_end_enr_long = mit_end_enr_long.sort_values(by=['endowment-fy-begin'])
mit_end_enr_long
# Out:
#    endowment-fy-begin               type  percentage        Type
# 0                2020  endowment-pct-chg      0.0610   Endowment
# 4                2020    ugtotal-pct-chg     -0.0373  Enrollment
# 1                2021  endowment-pct-chg      0.0575   Endowment
# 5                2021    ugtotal-pct-chg      0.0635  Enrollment
# 2                2022  endowment-pct-chg      0.4891   Endowment
# 6                2022    ugtotal-pct-chg      0.0041  Enrollment
# 3                2023  endowment-pct-chg     -0.1022   Endowment
# 7                2023    ugtotal-pct-chg     -0.0174  Enrollment

# %%
# creating dataframe for endowment coordinates
mit_end_coord = mit_end_enr_long[(mit_end_enr_long.Type == 'Endowment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
mit_end_coord['percentage'] = mit_end_coord['percentage'].apply(lambda x: round(x, 4))
mit_end_coord
# Out:
#    endowment-fy-begin  percentage
# 0                2020      0.0610
# 1                2021      0.0575
# 2                2022      0.4891
# 3                2023     -0.1022

# %%
# creating dataframe for enrollment coordinates
mit_enr_coord = mit_end_enr_long[(mit_end_enr_long.Type == 'Enrollment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
mit_enr_coord['percentage'] = mit_enr_coord['percentage'].apply(lambda x: round(x, 4))
mit_enr_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020     -0.0373
# 5                2021      0.0635
# 6                2022      0.0041
# 7                2023     -0.0174

# %%
# plotting total enrollment and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
mit_end_enr_plot = sns.lineplot(mit_end_enr_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(mit_end_enr_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points
for i, point in mit_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.125, str(point["percentage"]))

# annotate enrollment points
for i, point in mit_enr_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.125, str(point["percentage"]))


ax.set_title('2020-2023 MIT Endowment vs. Enrollment YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ### 5) University of California, Berkeley

# %%
# creating dataframe with only total endowment & total enrollment percentage changes
ucb_end_enr = ucb_df[['endowment-fy-begin', 'endowment-pct-chg', 'ugtotal-pct-chg']]

# %%
# removing year 2019 due to all 0 values
ucb_end_enr = ucb_end_enr.query('`endowment-fy-begin` != 2019').copy()
ucb_end_enr
# Out:
#     endowment-fy-begin  endowment-pct-chg  ugtotal-pct-chg
# 23                2020             0.0242          -0.0117
# 22                2021             0.3774           0.0375
# 21                2022            -0.0925           0.0214
# 20                2023             0.0943           0.0175

# %%
# converting total endowment and total enrollment to long data for multiline plot
ucb_end_enr_long = ucb_end_enr.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ugtotal-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
ucb_end_enr_long = ucb_end_enr_long.assign(Type=ucb_end_enr_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ugtotal-pct-chg' : 'Enrollment'}))

# %%
# sort by year (endowment-fy-begin) ASC
ucb_end_enr_long = ucb_end_enr_long.sort_values(by=['endowment-fy-begin'])
ucb_end_enr_long
# Out:
#    endowment-fy-begin               type  percentage        Type
# 0                2020  endowment-pct-chg      0.0242   Endowment
# 4                2020    ugtotal-pct-chg     -0.0117  Enrollment
# 1                2021  endowment-pct-chg      0.3774   Endowment
# 5                2021    ugtotal-pct-chg      0.0375  Enrollment
# 2                2022  endowment-pct-chg     -0.0925   Endowment
# 6                2022    ugtotal-pct-chg      0.0214  Enrollment
# 3                2023  endowment-pct-chg      0.0943   Endowment
# 7                2023    ugtotal-pct-chg      0.0175  Enrollment

# %%
# creating dataframe for endowment coordinates
ucb_end_coord = ucb_end_enr_long[(ucb_end_enr_long.Type == 'Endowment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
ucb_end_coord['percentage'] = ucb_end_coord['percentage'].apply(lambda x: round(x, 4))
ucb_end_coord
# Out:
#    endowment-fy-begin  percentage
# 0                2020      0.0242
# 1                2021      0.3774
# 2                2022     -0.0925
# 3                2023      0.0943

# %%
# creating dataframe for enrollment coordinates
ucb_enr_coord = ucb_end_enr_long[(ucb_end_enr_long.Type == 'Enrollment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
ucb_enr_coord['percentage'] = ucb_enr_coord['percentage'].apply(lambda x: round(x, 4))
ucb_enr_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020     -0.0117
# 5                2021      0.0375
# 6                2022      0.0214
# 7                2023      0.0175

# %%
# plotting total enrollment and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
ucb_end_enr_plot = sns.lineplot(ucb_end_enr_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(ucb_end_enr_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points
for i, point in ucb_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.125, str(point["percentage"]))

# annotate enrollment points
for i, point in ucb_enr_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.125, str(point["percentage"]))


ax.set_title('2020-2023 UCB Endowment vs. Enrollment YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ### 6) University of California, Los Angeles

# %%
# creating dataframe with only total endowment & total enrollment percentage changes
ucla_end_enr = ucla_df[['endowment-fy-begin', 'endowment-pct-chg', 'ugtotal-pct-chg']]

# %%
# removing year 2019 due to all 0 values
ucla_end_enr = ucla_end_enr.query('`endowment-fy-begin` != 2019').copy()
ucla_end_enr
# Out:
#     endowment-fy-begin  endowment-pct-chg  ugtotal-pct-chg
# 33                2020             0.0526           0.0029
# 32                2021             0.2750           0.0153
# 31                2022            -0.0196           0.0095
# 30                2023             0.1000           0.0190

# %%
# converting total endowment and total enrollment to long data for multiline plot
ucla_end_enr_long = ucla_end_enr.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ugtotal-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
ucla_end_enr_long = ucla_end_enr_long.assign(Type=ucla_end_enr_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ugtotal-pct-chg' : 'Enrollment'}))

# %%
# sort by year (endowment-fy-begin) ASC
ucla_end_enr_long = ucla_end_enr_long.sort_values(by=['endowment-fy-begin'])
ucla_end_enr_long
# Out:
#    endowment-fy-begin               type  percentage        Type
# 0                2020  endowment-pct-chg      0.0526   Endowment
# 4                2020    ugtotal-pct-chg      0.0029  Enrollment
# 1                2021  endowment-pct-chg      0.2750   Endowment
# 5                2021    ugtotal-pct-chg      0.0153  Enrollment
# 2                2022  endowment-pct-chg     -0.0196   Endowment
# 6                2022    ugtotal-pct-chg      0.0095  Enrollment
# 3                2023  endowment-pct-chg      0.1000   Endowment
# 7                2023    ugtotal-pct-chg      0.0190  Enrollment

# %%
# creating dataframe for endowment coordinates
ucla_end_coord = ucla_end_enr_long[(ucla_end_enr_long.Type == 'Endowment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
ucla_end_coord['percentage'] = ucla_end_coord['percentage'].apply(lambda x: round(x, 4))
ucla_end_coord
# Out:
#    endowment-fy-begin  percentage
# 0                2020      0.0526
# 1                2021      0.2750
# 2                2022     -0.0196
# 3                2023      0.1000

# %%
# creating dataframe for enrollment coordinates
ucla_enr_coord = ucla_end_enr_long[(ucla_end_enr_long.Type == 'Enrollment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
ucla_enr_coord['percentage'] = ucla_enr_coord['percentage'].apply(lambda x: round(x, 4))
ucla_enr_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020      0.0029
# 5                2021      0.0153
# 6                2022      0.0095
# 7                2023      0.0190

# %%
# plotting total enrollment and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
ucla_end_enr_plot = sns.lineplot(ucla_end_enr_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(ucla_end_enr_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points
for i, point in ucla_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.125, str(point["percentage"]))

# annotate enrollment points
for i, point in ucla_enr_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.125, str(point["percentage"]))


ax.set_title('2020-2023 UCLA Endowment vs. Enrollment YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ### 7) University of Pennsylvania

# %%
# creating dataframe with only total endowment & total enrollment percentage changes
upenn_end_enr = upenn_df[['endowment-fy-begin', 'endowment-pct-chg', 'ugtotal-pct-chg']]

# %%
# removing year 2019 due to all 0 values
upenn_end_enr = upenn_end_enr.query('`endowment-fy-begin` != 2019').copy()
upenn_end_enr
# Out:
#     endowment-fy-begin  endowment-pct-chg  ugtotal-pct-chg
# 38                2020             0.0136          -0.0147
# 37                2021             0.3758           0.0091
# 36                2022             0.0098          -0.0203
# 35                2023             0.0145           0.0241

# %%
# converting total endowment and total enrollment to long data for multiline plot
upenn_end_enr_long = upenn_end_enr.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ugtotal-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
upenn_end_enr_long = upenn_end_enr_long.assign(Type=upenn_end_enr_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ugtotal-pct-chg' : 'Enrollment'}))

# %%
# sort by year (endowment-fy-begin) ASC
upenn_end_enr_long = upenn_end_enr_long.sort_values(by=['endowment-fy-begin'])
upenn_end_enr_long
# Out:
#    endowment-fy-begin               type  percentage        Type
# 0                2020  endowment-pct-chg      0.0136   Endowment
# 4                2020    ugtotal-pct-chg     -0.0147  Enrollment
# 1                2021  endowment-pct-chg      0.3758   Endowment
# 5                2021    ugtotal-pct-chg      0.0091  Enrollment
# 2                2022  endowment-pct-chg      0.0098   Endowment
# 6                2022    ugtotal-pct-chg     -0.0203  Enrollment
# 3                2023  endowment-pct-chg      0.0145   Endowment
# 7                2023    ugtotal-pct-chg      0.0241  Enrollment

# %%
# creating dataframe for endowment coordinates
upenn_end_coord = upenn_end_enr_long[(upenn_end_enr_long.Type == 'Endowment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
upenn_end_coord['percentage'] = upenn_end_coord['percentage'].apply(lambda x: round(x, 4))
upenn_end_coord
# Out:
#    endowment-fy-begin  percentage
# 0                2020      0.0136
# 1                2021      0.3758
# 2                2022      0.0098
# 3                2023      0.0145

# %%
# creating dataframe for enrollment coordinates
upenn_enr_coord = upenn_end_enr_long[(upenn_end_enr_long.Type == 'Enrollment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
upenn_enr_coord['percentage'] = upenn_enr_coord['percentage'].apply(lambda x: round(x, 4))
upenn_enr_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020     -0.0147
# 5                2021      0.0091
# 6                2022     -0.0203
# 7                2023      0.0241

# %%
# plotting total enrollment and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
upenn_end_enr_plot = sns.lineplot(upenn_end_enr_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(upenn_end_enr_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points
for i, point in upenn_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.125, str(point["percentage"]))

# annotate enrollment points
for i, point in upenn_enr_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.125, str(point["percentage"]))


ax.set_title('2020-2023 UPenn Endowment vs. Enrollment YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ### 8) Harvard University

# %%
# creating dataframe with only total endowment & total enrollment percentage changes
harvard_end_enr = harvard_df[['endowment-fy-begin', 'endowment-pct-chg', 'ugtotal-pct-chg']]

# %%
# removing year 2019 due to all 0 values
harvard_end_enr = harvard_end_enr.query('`endowment-fy-begin` != 2019').copy()
harvard_end_enr
# Out:
#     endowment-fy-begin  endowment-pct-chg  ugtotal-pct-chg
# 43                2020             0.0244          -0.2269
# 42                2021             0.2697           0.3698
# 41                2022            -0.0432           0.0122
# 40                2023            -0.0039          -0.0246

# %%
# converting total endowment and total enrollment to long data for multiline plot
harvard_end_enr_long = harvard_end_enr.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ugtotal-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
harvard_end_enr_long = harvard_end_enr_long.assign(Type=harvard_end_enr_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ugtotal-pct-chg' : 'Enrollment'}))

# %%
# sort by year (endowment-fy-begin) ASC
harvard_end_enr_long = harvard_end_enr_long.sort_values(by=['endowment-fy-begin'])
harvard_end_enr_long
# Out:
#    endowment-fy-begin               type  percentage        Type
# 0                2020  endowment-pct-chg      0.0244   Endowment
# 4                2020    ugtotal-pct-chg     -0.2269  Enrollment
# 1                2021  endowment-pct-chg      0.2697   Endowment
# 5                2021    ugtotal-pct-chg      0.3698  Enrollment
# 2                2022  endowment-pct-chg     -0.0432   Endowment
# 6                2022    ugtotal-pct-chg      0.0122  Enrollment
# 3                2023  endowment-pct-chg     -0.0039   Endowment
# 7                2023    ugtotal-pct-chg     -0.0246  Enrollment

# %%
# creating dataframe for endowment coordinates
harvard_end_coord = harvard_end_enr_long[(harvard_end_enr_long.Type == 'Endowment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
harvard_end_coord['percentage'] = harvard_end_coord['percentage'].apply(lambda x: round(x, 4))
harvard_end_coord
# Out:
#    endowment-fy-begin  percentage
# 0                2020      0.0244
# 1                2021      0.2697
# 2                2022     -0.0432
# 3                2023     -0.0039

# %%
# creating dataframe for enrollment coordinates
harvard_enr_coord = harvard_end_enr_long[(harvard_end_enr_long.Type == 'Enrollment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
harvard_enr_coord['percentage'] = harvard_enr_coord['percentage'].apply(lambda x: round(x, 4))
harvard_enr_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020     -0.2269
# 5                2021      0.3698
# 6                2022      0.0122
# 7                2023     -0.0246

# %%
# plotting total enrollment and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
harvard_end_enr_plot = sns.lineplot(harvard_end_enr_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(harvard_end_enr_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points
for i, point in harvard_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.09, str(point["percentage"]))

# annotate enrollment points
for i, point in harvard_enr_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.05, str(point["percentage"]))


ax.set_title('2020-2023 Harvard Endowment vs. Enrollment YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ### 9) Williams College

# %%
# creating dataframe with only total endowment & total enrollment percentage changes
williams_end_enr = williams_df[['endowment-fy-begin', 'endowment-pct-chg', 'ugtotal-pct-chg']]

# %%
# removing year 2019 due to all 0 values
williams_end_enr = williams_end_enr.query('`endowment-fy-begin` != 2019').copy()
williams_end_enr
# Out:
#     endowment-fy-begin  endowment-pct-chg  ugtotal-pct-chg
# 48                2020            -0.0345          -0.0558
# 47                2021             0.5000           0.1040
# 46                2022            -0.1667          -0.0065
# 45                2023             0.0000          -0.0451

# %%
# converting total endowment and total enrollment to long data for multiline plot
williams_end_enr_long = williams_end_enr.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ugtotal-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
williams_end_enr_long = williams_end_enr_long.assign(Type=williams_end_enr_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ugtotal-pct-chg' : 'Enrollment'}))

# %%
# sort by year (endowment-fy-begin) ASC
williams_end_enr_long = williams_end_enr_long.sort_values(by=['endowment-fy-begin'])
williams_end_enr_long
# Out:
#    endowment-fy-begin               type  percentage        Type
# 0                2020  endowment-pct-chg     -0.0345   Endowment
# 4                2020    ugtotal-pct-chg     -0.0558  Enrollment
# 1                2021  endowment-pct-chg      0.5000   Endowment
# 5                2021    ugtotal-pct-chg      0.1040  Enrollment
# 2                2022  endowment-pct-chg     -0.1667   Endowment
# 6                2022    ugtotal-pct-chg     -0.0065  Enrollment
# 3                2023  endowment-pct-chg      0.0000   Endowment
# 7                2023    ugtotal-pct-chg     -0.0451  Enrollment

# %%
# creating dataframe for endowment coordinates
williams_end_coord = williams_end_enr_long[(williams_end_enr_long.Type == 'Endowment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
williams_end_coord['percentage'] = williams_end_coord['percentage'].apply(lambda x: round(x, 4))
williams_end_coord
# Out:
#    endowment-fy-begin  percentage
# 0                2020     -0.0345
# 1                2021      0.5000
# 2                2022     -0.1667
# 3                2023      0.0000

# %%
# creating dataframe for enrollment coordinates
williams_enr_coord = williams_end_enr_long[(williams_end_enr_long.Type == 'Enrollment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
williams_enr_coord['percentage'] = williams_enr_coord['percentage'].apply(lambda x: round(x, 4))
williams_enr_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020     -0.0558
# 5                2021      0.1040
# 6                2022     -0.0065
# 7                2023     -0.0451

# %%
# plotting total enrollment and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
williams_end_enr_plot = sns.lineplot(williams_end_enr_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(williams_end_enr_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points
for i, point in williams_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.105, str(point["percentage"]))

# annotate enrollment points
for i, point in williams_enr_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.101, str(point["percentage"]))


ax.set_title('2020-2023 Williams College Endowment vs. Enrollment YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ### 10) Amherst College

# %%
# creating dataframe with only total endowment & total enrollment percentage changes
amherst_end_enr = amherst_df[['endowment-fy-begin', 'endowment-pct-chg', 'ugtotal-pct-chg']]

# %%
# removing year 2019 due to all 0 values
amherst_end_enr = amherst_end_enr.query('`endowment-fy-begin` != 2019').copy()
amherst_end_enr
# Out:
#     endowment-fy-begin  endowment-pct-chg  ugtotal-pct-chg
# 53                2020             0.2738          -0.0511
# 52                2021             0.4698           0.1295
# 51                2022            -0.1274          -0.0370
# 50                2023             0.0050           0.0047

# %%
# converting total endowment and total enrollment to long data for multiline plot
amherst_end_enr_long = amherst_end_enr.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ugtotal-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
amherst_end_enr_long = amherst_end_enr_long.assign(Type=amherst_end_enr_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ugtotal-pct-chg' : 'Enrollment'}))

# %%
# sort by year (endowment-fy-begin) ASC
amherst_end_enr_long = amherst_end_enr_long.sort_values(by=['endowment-fy-begin'])
amherst_end_enr_long
# Out:
#    endowment-fy-begin               type  percentage        Type
# 0                2020  endowment-pct-chg      0.2738   Endowment
# 4                2020    ugtotal-pct-chg     -0.0511  Enrollment
# 1                2021  endowment-pct-chg      0.4698   Endowment
# 5                2021    ugtotal-pct-chg      0.1295  Enrollment
# 2                2022  endowment-pct-chg     -0.1274   Endowment
# 6                2022    ugtotal-pct-chg     -0.0370  Enrollment
# 3                2023  endowment-pct-chg      0.0050   Endowment
# 7                2023    ugtotal-pct-chg      0.0047  Enrollment

# %%
# creating dataframe for endowment coordinates
amherst_end_coord = amherst_end_enr_long[(amherst_end_enr_long.Type == 'Endowment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
amherst_end_coord['percentage'] = amherst_end_coord['percentage'].apply(lambda x: round(x, 4))
amherst_end_coord
# Out:
#    endowment-fy-begin  percentage
# 0                2020      0.2738
# 1                2021      0.4698
# 2                2022     -0.1274
# 3                2023      0.0050

# %%
# creating dataframe for enrollment coordinates
amherst_enr_coord = amherst_end_enr_long[(amherst_end_enr_long.Type == 'Enrollment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
amherst_enr_coord['percentage'] = amherst_enr_coord['percentage'].apply(lambda x: round(x, 4))
amherst_enr_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020     -0.0511
# 5                2021      0.1295
# 6                2022     -0.0370
# 7                2023      0.0047

# %%
# plotting total enrollment and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
amherst_end_enr_plot = sns.lineplot(amherst_end_enr_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(amherst_end_enr_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points
for i, point in amherst_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.099, str(point["percentage"]))

# annotate enrollment points
for i, point in amherst_enr_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.059, str(point["percentage"]))


ax.set_title('2020-2023 Amherst College Endowment vs. Enrollment YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# # **Total Endowment vs. First-Time UG Enrollment by University**

# %% [markdown]
# ### 1) Princeton

# %%
# creating dataframe with only total endowment & total enrollment percentage changes
princeton_end_firstenr = princeton_df[['endowment-fy-begin', 'endowment-pct-chg', 'ugfirst-time-pct-chg']]

# %%
# removing year 2019 due to all 0 values
princeton_end_firstenr = princeton_end_firstenr.query('`endowment-fy-begin` != 2019').copy()
princeton_end_firstenr
# Out:
#    endowment-fy-begin  endowment-pct-chg  ugfirst-time-pct-chg
# 3                2020             0.0077               -0.1416
# 2                2021             0.0038                0.1239
# 1                2022             0.4389                0.1623
# 0                2023            -0.0504               -0.0875

# %%
# converting total endowment and total enrollment to long data for multiline plot
princeton_end_firstenr_long = princeton_end_firstenr.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ugfirst-time-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
princeton_end_firstenr_long = princeton_end_firstenr_long.assign(Type=princeton_end_firstenr_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ugfirst-time-pct-chg' : 'Enrollment'}))

# %%
# sort by year (endowment-fy-begin) ASC
princeton_end_firstenr_long = princeton_end_firstenr_long.sort_values(by=['endowment-fy-begin'])
princeton_end_firstenr_long
# Out:
#    endowment-fy-begin                  type  percentage        Type
# 0                2020     endowment-pct-chg      0.0077   Endowment
# 4                2020  ugfirst-time-pct-chg     -0.1416  Enrollment
# 1                2021     endowment-pct-chg      0.0038   Endowment
# 5                2021  ugfirst-time-pct-chg      0.1239  Enrollment
# 2                2022     endowment-pct-chg      0.4389   Endowment
# 6                2022  ugfirst-time-pct-chg      0.1623  Enrollment
# 3                2023     endowment-pct-chg     -0.0504   Endowment
# 7                2023  ugfirst-time-pct-chg     -0.0875  Enrollment

# %%
# creating dataframe for enrollment coordinates
princeton_firstenr_coord = princeton_end_firstenr_long[(princeton_end_firstenr_long.Type == 'Enrollment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
princeton_firstenr_coord['percentage'] = princeton_firstenr_coord['percentage'].apply(lambda x: round(x, 4))
princeton_firstenr_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020     -0.1416
# 5                2021      0.1239
# 6                2022      0.1623
# 7                2023     -0.0875

# %%
# plotting total enrollment and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
princeton_end_firstenr_plot = sns.lineplot(princeton_end_firstenr_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(princeton_end_firstenr_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points (reusing coordinates already created in total endowment vs. total enrollment)
for i, point in princeton_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.125, str(point["percentage"]))

# annotate enrollment points
for i, point in princeton_firstenr_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.125, str(point["percentage"]))


ax.set_title('2020-2023 Princeton Total Endowment vs. First-Time Enrollment YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ### 2) Yale

# %%
# creating dataframe with only total endowment & total enrollment percentage changes
yale_end_firstenr = yale_df[['endowment-fy-begin', 'endowment-pct-chg', 'ugfirst-time-pct-chg']]

# %%
# removing year 2019 due to all 0 values
yale_end_firstenr = yale_end_firstenr.query('`endowment-fy-begin` != 2019').copy()
yale_end_firstenr
# Out:
#    endowment-fy-begin  endowment-pct-chg  ugfirst-time-pct-chg
# 8                2020             0.0328               -0.1845
# 7                2021             0.0293                0.4130
# 6                2022             0.3557               -0.1629
# 5                2023            -0.0213                0.0977

# %%
# converting total endowment and total enrollment to long data for multiline plot
yale_end_firstenr_long = yale_end_firstenr.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ugfirst-time-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
yale_end_firstenr_long = yale_end_firstenr_long.assign(Type=yale_end_firstenr_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ugfirst-time-pct-chg' : 'Enrollment'}))

# %%
# sort by year (endowment-fy-begin) ASC
yale_end_firstenr_long = yale_end_firstenr_long.sort_values(by=['endowment-fy-begin'])
yale_end_firstenr_long
# Out:
#    endowment-fy-begin                  type  percentage        Type
# 0                2020     endowment-pct-chg      0.0328   Endowment
# 4                2020  ugfirst-time-pct-chg     -0.1845  Enrollment
# 1                2021     endowment-pct-chg      0.0293   Endowment
# 5                2021  ugfirst-time-pct-chg      0.4130  Enrollment
# 2                2022     endowment-pct-chg      0.3557   Endowment
# 6                2022  ugfirst-time-pct-chg     -0.1629  Enrollment
# 3                2023     endowment-pct-chg     -0.0213   Endowment
# 7                2023  ugfirst-time-pct-chg      0.0977  Enrollment

# %%
# creating dataframe for enrollment coordinates
yale_firstenr_coord = yale_end_firstenr_long[(yale_end_firstenr_long.Type == 'Enrollment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
yale_firstenr_coord['percentage'] = yale_firstenr_coord['percentage'].apply(lambda x: round(x, 4))
yale_firstenr_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020     -0.1845
# 5                2021      0.4130
# 6                2022     -0.1629
# 7                2023      0.0977

# %%
# plotting total enrollment and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
yale_end_firstenr_plot = sns.lineplot(yale_end_firstenr_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(yale_end_firstenr_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points (reusing coordinates already created in total endowment vs. total enrollment)
for i, point in yale_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.125, str(point["percentage"]))

# annotate enrollment points
for i, point in yale_firstenr_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.125, str(point["percentage"]))


ax.set_title('2020-2023 Yale Total Endowment vs. First-Time Enrollment YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ### 3) Stanford

# %%
# creating dataframe with only total endowment & total enrollment percentage changes
stanford_end_firstenr = stanford_df[['endowment-fy-begin', 'endowment-pct-chg', 'ugfirst-time-pct-chg']]

# %%
# removing year 2019 due to all 0 values
stanford_end_firstenr = stanford_end_firstenr.query('`endowment-fy-begin` != 2019').copy()
stanford_end_firstenr
# Out:
#     endowment-fy-begin  endowment-pct-chg  ugfirst-time-pct-chg
# 13                2020             0.0453               -0.0553
# 12                2021             0.7040                0.0933
# 11                2022            -0.1992               -0.0120
# 10                2023            -0.0397               -0.0213

# %%
# converting total endowment and total enrollment to long data for multiline plot
stanford_end_firstenr_long = stanford_end_firstenr.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ugfirst-time-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
stanford_end_firstenr_long = stanford_end_firstenr_long.assign(Type=stanford_end_firstenr_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ugfirst-time-pct-chg' : 'Enrollment'}))

# %%
# sort by year (endowment-fy-begin) ASC
stanford_end_firstenr_long = stanford_end_firstenr_long.sort_values(by=['endowment-fy-begin'])
stanford_end_firstenr_long
# Out:
#    endowment-fy-begin                  type  percentage        Type
# 0                2020     endowment-pct-chg      0.0453   Endowment
# 4                2020  ugfirst-time-pct-chg     -0.0553  Enrollment
# 1                2021     endowment-pct-chg      0.7040   Endowment
# 5                2021  ugfirst-time-pct-chg      0.0933  Enrollment
# 2                2022     endowment-pct-chg     -0.1992   Endowment
# 6                2022  ugfirst-time-pct-chg     -0.0120  Enrollment
# 3                2023     endowment-pct-chg     -0.0397   Endowment
# 7                2023  ugfirst-time-pct-chg     -0.0213  Enrollment

# %%
# creating dataframe for enrollment coordinates
stanford_firstenr_coord = stanford_end_firstenr_long[(stanford_end_firstenr_long.Type == 'Enrollment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
stanford_firstenr_coord['percentage'] = stanford_firstenr_coord['percentage'].apply(lambda x: round(x, 4))
stanford_firstenr_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020     -0.0553
# 5                2021      0.0933
# 6                2022     -0.0120
# 7                2023     -0.0213

# %%
# plotting total enrollment and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
stanford_end_firstenr_plot = sns.lineplot(stanford_end_firstenr_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(stanford_end_firstenr_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points (reusing coordinates already created in total endowment vs. total enrollment)
for i, point in stanford_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.125, str(point["percentage"]))

# annotate enrollment points
for i, point in stanford_firstenr_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.125, str(point["percentage"]))


ax.set_title('2020-2023 Stanford Total Endowment vs. First-Time Enrollment YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ### 4) MIT

# %%
# creating dataframe with only total endowment & total enrollment percentage changes
mit_end_firstenr = mit_df[['endowment-fy-begin', 'endowment-pct-chg', 'ugfirst-time-pct-chg']]

# %%
# removing year 2019 due to all 0 values
mit_end_firstenr = mit_end_firstenr.query('`endowment-fy-begin` != 2019').copy()
mit_end_firstenr
# Out:
#     endowment-fy-begin  endowment-pct-chg  ugfirst-time-pct-chg
# 18                2020             0.0610               -0.0290
# 17                2021             0.0575                0.1000
# 16                2022             0.4891               -0.0348
# 15                2023            -0.1022               -0.0370

# %%
# converting total endowment and total enrollment to long data for multiline plot
mit_end_firstenr_long = mit_end_firstenr.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ugfirst-time-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
mit_end_firstenr_long = mit_end_firstenr_long.assign(Type=mit_end_firstenr_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ugfirst-time-pct-chg' : 'Enrollment'}))

# %%
# sort by year (endowment-fy-begin) ASC
mit_end_firstenr_long = mit_end_firstenr_long.sort_values(by=['endowment-fy-begin'])
mit_end_firstenr_long
# Out:
#    endowment-fy-begin                  type  percentage        Type
# 0                2020     endowment-pct-chg      0.0610   Endowment
# 4                2020  ugfirst-time-pct-chg     -0.0290  Enrollment
# 1                2021     endowment-pct-chg      0.0575   Endowment
# 5                2021  ugfirst-time-pct-chg      0.1000  Enrollment
# 2                2022     endowment-pct-chg      0.4891   Endowment
# 6                2022  ugfirst-time-pct-chg     -0.0348  Enrollment
# 3                2023     endowment-pct-chg     -0.1022   Endowment
# 7                2023  ugfirst-time-pct-chg     -0.0370  Enrollment

# %%
# creating dataframe for enrollment coordinates
mit_firstenr_coord = mit_end_firstenr_long[(mit_end_firstenr_long.Type == 'Enrollment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
mit_firstenr_coord['percentage'] = mit_firstenr_coord['percentage'].apply(lambda x: round(x, 4))
mit_firstenr_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020     -0.0290
# 5                2021      0.1000
# 6                2022     -0.0348
# 7                2023     -0.0370

# %%
# plotting total enrollment and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
mit_end_firstenr_plot = sns.lineplot(mit_end_firstenr_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(mit_end_firstenr_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points (reusing coordinates already created in total endowment vs. total enrollment)
for i, point in mit_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.125, str(point["percentage"]))

# annotate enrollment points
for i, point in mit_firstenr_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.125, str(point["percentage"]))


ax.set_title('2020-2023 MIT Total Endowment vs. First-Time Enrollment YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ### 5) University of California, Berkeley

# %%
# creating dataframe with only total endowment & total enrollment percentage changes
ucb_end_firstenr = ucb_df[['endowment-fy-begin', 'endowment-pct-chg', 'ugfirst-time-pct-chg']]

# %%
# removing year 2019 due to all 0 values
ucb_end_firstenr = ucb_end_firstenr.query('`endowment-fy-begin` != 2019').copy()
ucb_end_firstenr
# Out:
#     endowment-fy-begin  endowment-pct-chg  ugfirst-time-pct-chg
# 23                2020             0.0242               -0.0538
# 22                2021             0.3774                0.1331
# 21                2022            -0.0925               -0.0296
# 20                2023             0.0943               -0.0126

# %%
# converting total endowment and total enrollment to long data for multiline plot
ucb_end_firstenr_long = ucb_end_firstenr.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ugfirst-time-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
ucb_end_firstenr_long = ucb_end_firstenr_long.assign(Type=ucb_end_firstenr_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ugfirst-time-pct-chg' : 'Enrollment'}))

# %%
# sort by year (endowment-fy-begin) ASC
ucb_end_firstenr_long = ucb_end_firstenr_long.sort_values(by=['endowment-fy-begin'])
ucb_end_firstenr_long
# Out:
#    endowment-fy-begin                  type  percentage        Type
# 0                2020     endowment-pct-chg      0.0242   Endowment
# 4                2020  ugfirst-time-pct-chg     -0.0538  Enrollment
# 1                2021     endowment-pct-chg      0.3774   Endowment
# 5                2021  ugfirst-time-pct-chg      0.1331  Enrollment
# 2                2022     endowment-pct-chg     -0.0925   Endowment
# 6                2022  ugfirst-time-pct-chg     -0.0296  Enrollment
# 3                2023     endowment-pct-chg      0.0943   Endowment
# 7                2023  ugfirst-time-pct-chg     -0.0126  Enrollment

# %%
# creating dataframe for enrollment coordinates
ucb_firstenr_coord = ucb_end_firstenr_long[(ucb_end_firstenr_long.Type == 'Enrollment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
ucb_firstenr_coord['percentage'] = ucb_firstenr_coord['percentage'].apply(lambda x: round(x, 4))
ucb_firstenr_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020     -0.0538
# 5                2021      0.1331
# 6                2022     -0.0296
# 7                2023     -0.0126

# %%
# plotting total enrollment and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
ucb_end_firstenr_plot = sns.lineplot(ucb_end_firstenr_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(ucb_end_firstenr_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points (reusing coordinates already created in total endowment vs. total enrollment)
for i, point in ucb_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.125, str(point["percentage"]))

# annotate enrollment points
for i, point in ucb_firstenr_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.125, str(point["percentage"]))


ax.set_title('2020-2023 UCB Total Endowment vs. First-Time Enrollment YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ### 6) University of California, Los Angeles

# %%
# creating dataframe with only total endowment & total enrollment percentage changes
ucla_end_firstenr = ucla_df[['endowment-fy-begin', 'endowment-pct-chg', 'ugfirst-time-pct-chg']]

# %%
# removing year 2019 due to all 0 values
ucla_end_firstenr = ucla_end_firstenr.query('`endowment-fy-begin` != 2019').copy()
ucla_end_firstenr
# Out:
#     endowment-fy-begin  endowment-pct-chg  ugfirst-time-pct-chg
# 33                2020             0.0526                0.0787
# 32                2021             0.2750                0.0310
# 31                2022            -0.0196               -0.0187
# 30                2023             0.1000                0.0192

# %%
# converting total endowment and total enrollment to long data for multiline plot
ucla_end_firstenr_long = ucla_end_firstenr.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ugfirst-time-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
ucla_end_firstenr_long = ucla_end_firstenr_long.assign(Type=ucla_end_firstenr_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ugfirst-time-pct-chg' : 'Enrollment'}))

# %%
# sort by year (endowment-fy-begin) ASC
ucla_end_firstenr_long = ucla_end_firstenr_long.sort_values(by=['endowment-fy-begin'])
ucla_end_firstenr_long
# Out:
#    endowment-fy-begin                  type  percentage        Type
# 0                2020     endowment-pct-chg      0.0526   Endowment
# 4                2020  ugfirst-time-pct-chg      0.0787  Enrollment
# 1                2021     endowment-pct-chg      0.2750   Endowment
# 5                2021  ugfirst-time-pct-chg      0.0310  Enrollment
# 2                2022     endowment-pct-chg     -0.0196   Endowment
# 6                2022  ugfirst-time-pct-chg     -0.0187  Enrollment
# 3                2023     endowment-pct-chg      0.1000   Endowment
# 7                2023  ugfirst-time-pct-chg      0.0192  Enrollment

# %%
# creating dataframe for enrollment coordinates
ucla_firstenr_coord = ucla_end_firstenr_long[(ucla_end_firstenr_long.Type == 'Enrollment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
ucla_firstenr_coord['percentage'] = ucla_firstenr_coord['percentage'].apply(lambda x: round(x, 4))
ucla_firstenr_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020      0.0787
# 5                2021      0.0310
# 6                2022     -0.0187
# 7                2023      0.0192

# %%
# plotting total enrollment and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
ucla_end_firstenr_plot = sns.lineplot(ucla_end_firstenr_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(ucla_end_firstenr_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points (reusing coordinates already created in total endowment vs. total enrollment)
for i, point in ucla_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.125, str(point["percentage"]))

# annotate enrollment points
for i, point in ucla_firstenr_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.125, str(point["percentage"]))


ax.set_title('2020-2023 UCLA Total Endowment vs. First-Time Enrollment YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ### 7) University of Pennsylvania

# %%
# creating dataframe with only total endowment & total enrollment percentage changes
upenn_end_firstenr = upenn_df[['endowment-fy-begin', 'endowment-pct-chg', 'ugfirst-time-pct-chg']]

# %%
# removing year 2019 due to all 0 values
upenn_end_firstenr = upenn_end_firstenr.query('`endowment-fy-begin` != 2019').copy()
upenn_end_firstenr
# Out:
#     endowment-fy-begin  endowment-pct-chg  ugfirst-time-pct-chg
# 38                2020             0.0136               -0.0235
# 37                2021             0.3758                0.0232
# 36                2022             0.0098                0.0329
# 35                2023             0.0145                0.0000

# %%
# converting total endowment and total enrollment to long data for multiline plot
upenn_end_firstenr_long = upenn_end_firstenr.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ugfirst-time-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
upenn_end_firstenr_long = upenn_end_firstenr_long.assign(Type=upenn_end_firstenr_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ugfirst-time-pct-chg' : 'Enrollment'}))

# %%
# sort by year (endowment-fy-begin) ASC
upenn_end_firstenr_long = upenn_end_firstenr_long.sort_values(by=['endowment-fy-begin'])
upenn_end_firstenr_long
# Out:
#    endowment-fy-begin                  type  percentage        Type
# 0                2020     endowment-pct-chg      0.0136   Endowment
# 4                2020  ugfirst-time-pct-chg     -0.0235  Enrollment
# 1                2021     endowment-pct-chg      0.3758   Endowment
# 5                2021  ugfirst-time-pct-chg      0.0232  Enrollment
# 2                2022     endowment-pct-chg      0.0098   Endowment
# 6                2022  ugfirst-time-pct-chg      0.0329  Enrollment
# 3                2023     endowment-pct-chg      0.0145   Endowment
# 7                2023  ugfirst-time-pct-chg      0.0000  Enrollment

# %%
# creating dataframe for enrollment coordinates
upenn_firstenr_coord = upenn_end_firstenr_long[(upenn_end_firstenr_long.Type == 'Enrollment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
upenn_firstenr_coord['percentage'] = upenn_firstenr_coord['percentage'].apply(lambda x: round(x, 4))
upenn_firstenr_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020     -0.0235
# 5                2021      0.0232
# 6                2022      0.0329
# 7                2023      0.0000

# %%
# plotting total enrollment and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
upenn_end_firstenr_plot = sns.lineplot(upenn_end_firstenr_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(upenn_end_firstenr_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points (reusing coordinates already created in total endowment vs. total enrollment)
for i, point in upenn_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.125, str(point["percentage"]))

# annotate enrollment points
for i, point in upenn_firstenr_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.125, str(point["percentage"]))


ax.set_title('2020-2023 UPenn Total Endowment vs. First-Time Enrollment YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ### 8) Harvard University

# %%
# creating dataframe with only total endowment & total enrollment percentage changes
harvard_end_firstenr = harvard_df[['endowment-fy-begin', 'endowment-pct-chg', 'ugfirst-time-pct-chg']]

# %%
# removing year 2019 due to all 0 values
harvard_end_firstenr = harvard_end_firstenr.query('`endowment-fy-begin` != 2019').copy()
harvard_end_firstenr
# Out:
#     endowment-fy-begin  endowment-pct-chg  ugfirst-time-pct-chg
# 43                2020             0.0244               -0.1472
# 42                2021             0.2697                0.3902
# 41                2022            -0.0432               -0.1565
# 40                2023            -0.0039                0.0000

# %%
# converting total endowment and total enrollment to long data for multiline plot
harvard_end_firstenr_long = harvard_end_firstenr.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ugfirst-time-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
harvard_end_firstenr_long = harvard_end_firstenr_long.assign(Type=harvard_end_firstenr_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ugfirst-time-pct-chg' : 'Enrollment'}))

# %%
# sort by year (endowment-fy-begin) ASC
harvard_end_firstenr_long = harvard_end_firstenr_long.sort_values(by=['endowment-fy-begin'])
harvard_end_firstenr_long
# Out:
#    endowment-fy-begin                  type  percentage        Type
# 0                2020     endowment-pct-chg      0.0244   Endowment
# 4                2020  ugfirst-time-pct-chg     -0.1472  Enrollment
# 1                2021     endowment-pct-chg      0.2697   Endowment
# 5                2021  ugfirst-time-pct-chg      0.3902  Enrollment
# 2                2022     endowment-pct-chg     -0.0432   Endowment
# 6                2022  ugfirst-time-pct-chg     -0.1565  Enrollment
# 3                2023     endowment-pct-chg     -0.0039   Endowment
# 7                2023  ugfirst-time-pct-chg      0.0000  Enrollment

# %%
# creating dataframe for enrollment coordinates
harvard_firstenr_coord = harvard_end_firstenr_long[(harvard_end_firstenr_long.Type == 'Enrollment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
harvard_firstenr_coord['percentage'] = harvard_firstenr_coord['percentage'].apply(lambda x: round(x, 4))
harvard_firstenr_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020     -0.1472
# 5                2021      0.3902
# 6                2022     -0.1565
# 7                2023      0.0000

# %%
# plotting total enrollment and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
harvard_end_firstenr_plot = sns.lineplot(harvard_end_firstenr_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(harvard_end_firstenr_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points (reusing coordinates already created in total endowment vs. total enrollment)
for i, point in harvard_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.125, str(point["percentage"]))

# annotate enrollment points
for i, point in harvard_firstenr_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.125, str(point["percentage"]))


ax.set_title('2020-2023 Harvard Total Endowment vs. First-Time Enrollment YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ### 9) Williams College

# %%
# creating dataframe with only total endowment & total enrollment percentage changes
williams_end_firstenr = williams_df[['endowment-fy-begin', 'endowment-pct-chg', 'ugfirst-time-pct-chg']]

# %%
# removing year 2019 due to all 0 values
williams_end_firstenr = williams_end_firstenr.query('`endowment-fy-begin` != 2019').copy()
williams_end_firstenr
# Out:
#     endowment-fy-begin  endowment-pct-chg  ugfirst-time-pct-chg
# 48                2020            -0.0345               -0.1172
# 47                2021             0.5000                0.1909
# 46                2022            -0.1667                0.0052
# 45                2023             0.0000               -0.0624

# %%
# converting total endowment and total enrollment to long data for multiline plot
williams_end_firstenr_long = williams_end_firstenr.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ugfirst-time-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
williams_end_firstenr_long = williams_end_firstenr_long.assign(Type=williams_end_firstenr_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ugfirst-time-pct-chg' : 'Enrollment'}))

# %%
# sort by year (endowment-fy-begin) ASC
williams_end_firstenr_long = williams_end_firstenr_long.sort_values(by=['endowment-fy-begin'])
williams_end_firstenr_long
# Out:
#    endowment-fy-begin                  type  percentage        Type
# 0                2020     endowment-pct-chg     -0.0345   Endowment
# 4                2020  ugfirst-time-pct-chg     -0.1172  Enrollment
# 1                2021     endowment-pct-chg      0.5000   Endowment
# 5                2021  ugfirst-time-pct-chg      0.1909  Enrollment
# 2                2022     endowment-pct-chg     -0.1667   Endowment
# 6                2022  ugfirst-time-pct-chg      0.0052  Enrollment
# 3                2023     endowment-pct-chg      0.0000   Endowment
# 7                2023  ugfirst-time-pct-chg     -0.0624  Enrollment

# %%
# creating dataframe for enrollment coordinates
williams_firstenr_coord = williams_end_firstenr_long[(williams_end_firstenr_long.Type == 'Enrollment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
williams_firstenr_coord['percentage'] = williams_firstenr_coord['percentage'].apply(lambda x: round(x, 4))
williams_firstenr_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020     -0.1172
# 5                2021      0.1909
# 6                2022      0.0052
# 7                2023     -0.0624

# %%
# plotting total enrollment and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
williams_end_firstenr_plot = sns.lineplot(williams_end_firstenr_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(williams_end_firstenr_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points (reusing coordinates already created in total endowment vs. total enrollment)
for i, point in williams_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.125, str(point["percentage"]))

# annotate enrollment points
for i, point in williams_firstenr_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.125, str(point["percentage"]))


ax.set_title('2020-2023 Williams College Total Endowment vs. First-Time Enrollment YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ### 10) Amherst College

# %%
# creating dataframe with only total endowment & total enrollment percentage changes
amherst_end_firstenr = amherst_df[['endowment-fy-begin', 'endowment-pct-chg', 'ugfirst-time-pct-chg']]

# %%
# removing year 2019 due to all 0 values
amherst_end_firstenr = amherst_end_firstenr.query('`endowment-fy-begin` != 2019').copy()
amherst_end_firstenr
# Out:
#     endowment-fy-begin  endowment-pct-chg  ugfirst-time-pct-chg
# 53                2020             0.2738               -0.0766
# 52                2021             0.4698                0.1843
# 51                2022            -0.1274               -0.0914
# 50                2023             0.0050                0.0450

# %%
# converting total endowment and total enrollment to long data for multiline plot
amherst_end_firstenr_long = amherst_end_firstenr.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ugfirst-time-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
amherst_end_firstenr_long = amherst_end_firstenr_long.assign(Type=amherst_end_firstenr_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ugfirst-time-pct-chg' : 'Enrollment'}))

# %%
# sort by year (endowment-fy-begin) ASC
amherst_end_firstenr_long = amherst_end_firstenr_long.sort_values(by=['endowment-fy-begin'])
amherst_end_firstenr_long
# Out:
#    endowment-fy-begin                  type  percentage        Type
# 0                2020     endowment-pct-chg      0.2738   Endowment
# 4                2020  ugfirst-time-pct-chg     -0.0766  Enrollment
# 1                2021     endowment-pct-chg      0.4698   Endowment
# 5                2021  ugfirst-time-pct-chg      0.1843  Enrollment
# 2                2022     endowment-pct-chg     -0.1274   Endowment
# 6                2022  ugfirst-time-pct-chg     -0.0914  Enrollment
# 3                2023     endowment-pct-chg      0.0050   Endowment
# 7                2023  ugfirst-time-pct-chg      0.0450  Enrollment

# %%
# creating dataframe for enrollment coordinates
amherst_firstenr_coord = amherst_end_firstenr_long[(amherst_end_firstenr_long.Type == 'Enrollment')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
amherst_firstenr_coord['percentage'] = amherst_firstenr_coord['percentage'].apply(lambda x: round(x, 4))
amherst_firstenr_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020     -0.0766
# 5                2021      0.1843
# 6                2022     -0.0914
# 7                2023      0.0450

# %%
# plotting total enrollment and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
amherst_end_firstenr_plot = sns.lineplot(amherst_end_firstenr_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(amherst_end_firstenr_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points (reusing coordinates already created in total endowment vs. total enrollment)
for i, point in amherst_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.125, str(point["percentage"]))

# annotate enrollment points
for i, point in amherst_firstenr_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.125, str(point["percentage"]))


ax.set_title('2020-2023 Amherst College Total Endowment vs. First-Time Enrollment YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# # **Total Endowment vs. First-Time UG Admitted by University**

# %% [markdown]
# ### 1) Princeton

# %%
# creating dataframe with only total endowment & total admittance percentage changes
princeton_end_adm = princeton_df[['endowment-fy-begin', 'endowment-pct-chg', 'ug-admitted-pct-chg']]

# %%
# removing year 2019 due to all 0 values
princeton_end_adm = princeton_end_adm.query('`endowment-fy-begin` != 2019').copy()
princeton_end_adm
# Out:
#    endowment-fy-begin  endowment-pct-chg  ug-admitted-pct-chg
# 3                2020             0.0077              -0.0248
# 2                2021             0.0038              -0.1088
# 1                2022             0.4389               0.3157
# 0                2023            -0.0504              -0.1777

# %%
# converting total endowment and total admittance to long data for multiline plot
princeton_end_adm_long = princeton_end_adm.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ug-admitted-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
princeton_end_adm_long = princeton_end_adm_long.assign(Type=princeton_end_adm_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ug-admitted-pct-chg' : 'Admitted'}))

# %%
# sort by year (endowment-fy-begin) ASC
princeton_end_adm_long = princeton_end_adm_long.sort_values(by=['endowment-fy-begin'])
princeton_end_adm_long
# Out:
#    endowment-fy-begin                 type  percentage       Type
# 0                2020    endowment-pct-chg      0.0077  Endowment
# 4                2020  ug-admitted-pct-chg     -0.0248   Admitted
# 1                2021    endowment-pct-chg      0.0038  Endowment
# 5                2021  ug-admitted-pct-chg     -0.1088   Admitted
# 2                2022    endowment-pct-chg      0.4389  Endowment
# 6                2022  ug-admitted-pct-chg      0.3157   Admitted
# 3                2023    endowment-pct-chg     -0.0504  Endowment
# 7                2023  ug-admitted-pct-chg     -0.1777   Admitted

# %%
# creating dataframe for admitted coordinates
princeton_adm_coord = princeton_end_adm_long[(princeton_end_adm_long.Type == 'Admitted')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
princeton_adm_coord['percentage'] = princeton_adm_coord['percentage'].apply(lambda x: round(x, 4))
princeton_adm_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020     -0.0248
# 5                2021     -0.1088
# 6                2022      0.3157
# 7                2023     -0.1777

# %%
# plotting total endowment and total admittance in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
princeton_end_adm_plot = sns.lineplot(princeton_end_adm_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(princeton_end_adm_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points (reusing coordinates already created in total endowment vs. total enrollment)
for i, point in princeton_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.125, str(point["percentage"]))

# annotate admittance points
for i, point in princeton_adm_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.125, str(point["percentage"]))


ax.set_title('2020-2023 Princeton Total Endowment vs. First-Time Admittance YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ### 2) Yale

# %%
# creating dataframe with only total endowment & total admittance percentage changes
yale_end_adm = yale_df[['endowment-fy-begin', 'endowment-pct-chg', 'ug-admitted-pct-chg']]

# %%
# removing year 2019 due to all 0 values
yale_end_adm = yale_end_adm.query('`endowment-fy-begin` != 2019').copy()
yale_end_adm
# Out:
#    endowment-fy-begin  endowment-pct-chg  ug-admitted-pct-chg
# 8                2020             0.0328               0.0259
# 7                2021             0.0293               0.0913
# 6                2022             0.3557              -0.0877
# 5                2023            -0.0213               0.0188

# %%
# converting total endowment and total admittance to long data for multiline plot
yale_end_adm_long = yale_end_adm.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ug-admitted-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
yale_end_adm_long = yale_end_adm_long.assign(Type=yale_end_adm_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ug-admitted-pct-chg' : 'Admitted'}))

# %%
# sort by year (endowment-fy-begin) ASC
yale_end_adm_long = yale_end_adm_long.sort_values(by=['endowment-fy-begin'])
yale_end_adm_long
# Out:
#    endowment-fy-begin                 type  percentage       Type
# 0                2020    endowment-pct-chg      0.0328  Endowment
# 4                2020  ug-admitted-pct-chg      0.0259   Admitted
# 1                2021    endowment-pct-chg      0.0293  Endowment
# 5                2021  ug-admitted-pct-chg      0.0913   Admitted
# 2                2022    endowment-pct-chg      0.3557  Endowment
# 6                2022  ug-admitted-pct-chg     -0.0877   Admitted
# 3                2023    endowment-pct-chg     -0.0213  Endowment
# 7                2023  ug-admitted-pct-chg      0.0188   Admitted

# %%
# creating dataframe for admitted coordinates
yale_adm_coord = yale_end_adm_long[(yale_end_adm_long.Type == 'Admitted')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
yale_adm_coord['percentage'] = yale_adm_coord['percentage'].apply(lambda x: round(x, 4))
yale_adm_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020      0.0259
# 5                2021      0.0913
# 6                2022     -0.0877
# 7                2023      0.0188

# %%
# plotting total endowment and total admittance in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
yale_end_adm_plot = sns.lineplot(yale_end_adm_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(yale_end_adm_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points (reusing coordinates already created in total endowment vs. total enrollment)
for i, point in yale_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.125, str(point["percentage"]))

# annotate admittance points
for i, point in yale_adm_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.125, str(point["percentage"]))


ax.set_title('2020-2023 Yale Total Endowment vs. First-Time Admittance YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ### 3) Stanford

# %%
# creating dataframe with only total endowment & total admittance percentage changes
stanford_end_adm = stanford_df[['endowment-fy-begin', 'endowment-pct-chg', 'ug-admitted-pct-chg']]

# %%
# removing year 2019 due to all 0 values
stanford_end_adm = stanford_end_adm.query('`endowment-fy-begin` != 2019').copy()
stanford_end_adm
# Out:
#     endowment-fy-begin  endowment-pct-chg  ug-admitted-pct-chg
# 13                2020             0.0453               0.1392
# 12                2021             0.7040              -0.0677
# 11                2022            -0.1992              -0.0525
# 10                2023            -0.0397               0.0116

# %%
# converting total endowment and total admittance to long data for multiline plot
stanford_end_adm_long = stanford_end_adm.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ug-admitted-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
stanford_end_adm_long = stanford_end_adm_long.assign(Type=stanford_end_adm_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ug-admitted-pct-chg' : 'Admitted'}))

# %%
# sort by year (endowment-fy-begin) ASC
stanford_end_adm_long = stanford_end_adm_long.sort_values(by=['endowment-fy-begin'])
stanford_end_adm_long
# Out:
#    endowment-fy-begin                 type  percentage       Type
# 0                2020    endowment-pct-chg      0.0453  Endowment
# 4                2020  ug-admitted-pct-chg      0.1392   Admitted
# 1                2021    endowment-pct-chg      0.7040  Endowment
# 5                2021  ug-admitted-pct-chg     -0.0677   Admitted
# 2                2022    endowment-pct-chg     -0.1992  Endowment
# 6                2022  ug-admitted-pct-chg     -0.0525   Admitted
# 3                2023    endowment-pct-chg     -0.0397  Endowment
# 7                2023  ug-admitted-pct-chg      0.0116   Admitted

# %%
# creating dataframe for admitted coordinates
stanford_adm_coord = stanford_end_adm_long[(stanford_end_adm_long.Type == 'Admitted')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
stanford_adm_coord['percentage'] = stanford_adm_coord['percentage'].apply(lambda x: round(x, 4))
stanford_adm_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020      0.1392
# 5                2021     -0.0677
# 6                2022     -0.0525
# 7                2023      0.0116

# %%
# plotting total endowment and total admittance in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
stanford_end_adm_plot = sns.lineplot(stanford_end_adm_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(stanford_end_adm_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points (reusing coordinates already created in total endowment vs. total enrollment)
for i, point in stanford_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.125, str(point["percentage"]))

# annotate admittance points
for i, point in stanford_adm_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.125, str(point["percentage"]))


ax.set_title('2020-2023 Stanford Total Endowment vs. First-Time Admittance YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ### 4) MIT

# %%
# creating dataframe with only total endowment & total admittance percentage changes
mit_end_adm = mit_df[['endowment-fy-begin', 'endowment-pct-chg', 'ug-admitted-pct-chg']]

# %%
# removing year 2019 due to all 0 values
mit_end_adm = mit_end_adm.query('`endowment-fy-begin` != 2019').copy()
mit_end_adm
# Out:
#     endowment-fy-begin  endowment-pct-chg  ug-admitted-pct-chg
# 18                2020             0.0610               0.0210
# 17                2021             0.0575              -0.0631
# 16                2022             0.4891              -0.0205
# 15                2023            -0.1022              -0.0344

# %%
# converting total endowment and total admittance to long data for multiline plot
mit_end_adm_long = mit_end_adm.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ug-admitted-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
mit_end_adm_long = mit_end_adm_long.assign(Type=mit_end_adm_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ug-admitted-pct-chg' : 'Admitted'}))

# %%
# sort by year (endowment-fy-begin) ASC
mit_end_adm_long = mit_end_adm_long.sort_values(by=['endowment-fy-begin'])
mit_end_adm_long
# Out:
#    endowment-fy-begin                 type  percentage       Type
# 0                2020    endowment-pct-chg      0.0610  Endowment
# 4                2020  ug-admitted-pct-chg      0.0210   Admitted
# 1                2021    endowment-pct-chg      0.0575  Endowment
# 5                2021  ug-admitted-pct-chg     -0.0631   Admitted
# 2                2022    endowment-pct-chg      0.4891  Endowment
# 6                2022  ug-admitted-pct-chg     -0.0205   Admitted
# 3                2023    endowment-pct-chg     -0.1022  Endowment
# 7                2023  ug-admitted-pct-chg     -0.0344   Admitted

# %%
# creating dataframe for admitted coordinates
mit_adm_coord = mit_end_adm_long[(mit_end_adm_long.Type == 'Admitted')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
mit_adm_coord['percentage'] = mit_adm_coord['percentage'].apply(lambda x: round(x, 4))
mit_adm_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020      0.0210
# 5                2021     -0.0631
# 6                2022     -0.0205
# 7                2023     -0.0344

# %%
# plotting total admittance and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
mit_end_adm_plot = sns.lineplot(mit_end_adm_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(mit_end_adm_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points (reusing coordinates already created in total endowment vs. total enrollment)
for i, point in mit_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.125, str(point["percentage"]))

# annotate admittance points
for i, point in mit_adm_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.125, str(point["percentage"]))


ax.set_title('2020-2023 MIT Total Endowment vs. First-Time Admittance YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ### 5) University of California, Berekeley

# %%
# creating dataframe with only total endowment & total admittance percentage changes
ucb_end_adm = ucb_df[['endowment-fy-begin', 'endowment-pct-chg', 'ug-admitted-pct-chg']]

# %%
# removing year 2019 due to all 0 values
ucb_end_adm = ucb_end_adm.query('`endowment-fy-begin` != 2019').copy()
ucb_end_adm
# Out:
#     endowment-fy-begin  endowment-pct-chg  ug-admitted-pct-chg
# 23                2020             0.0242               0.0776
# 22                2021             0.3774               0.0262
# 21                2022            -0.0925              -0.1030
# 20                2023             0.0943               0.0039

# %%
# converting total endowment and total admittance to long data for multiline plot
ucb_end_adm_long = ucb_end_adm.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ug-admitted-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
ucb_end_adm_long = ucb_end_adm_long.assign(Type=ucb_end_adm_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ug-admitted-pct-chg' : 'Admitted'}))

# %%
# sort by year (endowment-fy-begin) ASC
ucb_end_adm_long = ucb_end_adm_long.sort_values(by=['endowment-fy-begin'])
ucb_end_adm_long
# Out:
#    endowment-fy-begin                 type  percentage       Type
# 0                2020    endowment-pct-chg      0.0242  Endowment
# 4                2020  ug-admitted-pct-chg      0.0776   Admitted
# 1                2021    endowment-pct-chg      0.3774  Endowment
# 5                2021  ug-admitted-pct-chg      0.0262   Admitted
# 2                2022    endowment-pct-chg     -0.0925  Endowment
# 6                2022  ug-admitted-pct-chg     -0.1030   Admitted
# 3                2023    endowment-pct-chg      0.0943  Endowment
# 7                2023  ug-admitted-pct-chg      0.0039   Admitted

# %%
# creating dataframe for admitted coordinates
ucb_adm_coord = ucb_end_adm_long[(ucb_end_adm_long.Type == 'Admitted')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
ucb_adm_coord['percentage'] = ucb_adm_coord['percentage'].apply(lambda x: round(x, 4))
ucb_adm_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020      0.0776
# 5                2021      0.0262
# 6                2022     -0.1030
# 7                2023      0.0039

# %%
# plotting total admittance and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
ucb_end_adm_plot = sns.lineplot(ucb_end_adm_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(ucb_end_adm_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points (reusing coordinates already created in total endowment vs. total enrollment)
for i, point in ucb_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.125, str(point["percentage"]))

# annotate admittance points
for i, point in ucb_adm_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.125, str(point["percentage"]))


ax.set_title('2020-2023 UCB Total Endowment vs. First-Time Admittance YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ### 6) University of California, Los Angeles

# %%
# creating dataframe with only total endowment & total admittance percentage changes
ucla_end_adm = ucla_df[['endowment-fy-begin', 'endowment-pct-chg', 'ug-admitted-pct-chg']]

# %%
# removing year 2019 due to all 0 values
ucla_end_adm = ucla_end_adm.query('`endowment-fy-begin` != 2019').copy()
ucla_end_adm
# Out:
#     endowment-fy-begin  endowment-pct-chg  ug-admitted-pct-chg
# 33                2020             0.0526               0.1616
# 32                2021             0.2750              -0.0368
# 31                2022            -0.0196              -0.1453
# 30                2023             0.1000              -0.0083

# %%
# converting total endowment and total admittance to long data for multiline plot
ucla_end_adm_long = ucla_end_adm.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ug-admitted-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
ucla_end_adm_long = ucla_end_adm_long.assign(Type=ucla_end_adm_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ug-admitted-pct-chg' : 'Admitted'}))

# %%
# sort by year (endowment-fy-begin) ASC
ucla_end_adm_long = ucla_end_adm_long.sort_values(by=['endowment-fy-begin'])
ucla_end_adm_long
# Out:
#    endowment-fy-begin                 type  percentage       Type
# 0                2020    endowment-pct-chg      0.0526  Endowment
# 4                2020  ug-admitted-pct-chg      0.1616   Admitted
# 1                2021    endowment-pct-chg      0.2750  Endowment
# 5                2021  ug-admitted-pct-chg     -0.0368   Admitted
# 2                2022    endowment-pct-chg     -0.0196  Endowment
# 6                2022  ug-admitted-pct-chg     -0.1453   Admitted
# 3                2023    endowment-pct-chg      0.1000  Endowment
# 7                2023  ug-admitted-pct-chg     -0.0083   Admitted

# %%
# creating dataframe for admitted coordinates
ucla_adm_coord = ucla_end_adm_long[(ucla_end_adm_long.Type == 'Admitted')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
ucla_adm_coord['percentage'] = ucla_adm_coord['percentage'].apply(lambda x: round(x, 4))
ucla_adm_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020      0.1616
# 5                2021     -0.0368
# 6                2022     -0.1453
# 7                2023     -0.0083

# %%
# plotting total enrollment and total admittance in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
ucla_end_adm_plot = sns.lineplot(ucla_end_adm_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(ucla_end_adm_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points (reusing coordinates already created in total endowment vs. total enrollment)
for i, point in ucla_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.125, str(point["percentage"]))

# annotate admittance points
for i, point in ucla_adm_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.125, str(point["percentage"]))


ax.set_title('2020-2023 UCLA Total Endowment vs. First-Time Admittance YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ### 7) University of Pennsylvania

# %%
# creating dataframe with only total endowment & total admittance percentage changes
upenn_end_adm = upenn_df[['endowment-fy-begin', 'endowment-pct-chg', 'ug-admitted-pct-chg']]

# %%
# removing year 2019 due to all 0 values
upenn_end_adm = upenn_end_adm.query('`endowment-fy-begin` != 2019').copy()
upenn_end_adm
# Out:
#     endowment-fy-begin  endowment-pct-chg  ug-admitted-pct-chg
# 38                2020             0.0136               0.0995
# 37                2021             0.3758              -0.1280
# 36                2022             0.0098               0.0742
# 35                2023             0.0145              -0.0169

# %%
# converting total endowment and total admittance to long data for multiline plot
upenn_end_adm_long = upenn_end_adm.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ug-admitted-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
upenn_end_adm_long = upenn_end_adm_long.assign(Type=upenn_end_adm_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ug-admitted-pct-chg' : 'Admitted'}))

# %%
# sort by year (endowment-fy-begin) ASC
upenn_end_adm_long = upenn_end_adm_long.sort_values(by=['endowment-fy-begin'])
upenn_end_adm_long
# Out:
#    endowment-fy-begin                 type  percentage       Type
# 0                2020    endowment-pct-chg      0.0136  Endowment
# 4                2020  ug-admitted-pct-chg      0.0995   Admitted
# 1                2021    endowment-pct-chg      0.3758  Endowment
# 5                2021  ug-admitted-pct-chg     -0.1280   Admitted
# 2                2022    endowment-pct-chg      0.0098  Endowment
# 6                2022  ug-admitted-pct-chg      0.0742   Admitted
# 3                2023    endowment-pct-chg      0.0145  Endowment
# 7                2023  ug-admitted-pct-chg     -0.0169   Admitted

# %%
# creating dataframe for admitted coordinates
upenn_adm_coord = upenn_end_adm_long[(upenn_end_adm_long.Type == 'Admitted')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
upenn_adm_coord['percentage'] = upenn_adm_coord['percentage'].apply(lambda x: round(x, 4))
upenn_adm_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020      0.0995
# 5                2021     -0.1280
# 6                2022      0.0742
# 7                2023     -0.0169

# %%
# plotting total admittance and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
upenn_end_adm_plot = sns.lineplot(upenn_end_adm_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(upenn_end_adm_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points (reusing coordinates already created in total endowment vs. total enrollment)
for i, point in upenn_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.125, str(point["percentage"]))

# annotate admittance points
for i, point in upenn_adm_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.125, str(point["percentage"]))


ax.set_title('2020-2023 UPenn Total Endowment vs. First-Time Admittance YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ### 8) Harvard University

# %%
# creating dataframe with only total endowment & total admittance percentage changes
harvard_end_adm = harvard_df[['endowment-fy-begin', 'endowment-pct-chg', 'ug-admitted-pct-chg']]

# %%
# removing year 2019 due to all 0 values
harvard_end_adm = harvard_end_adm.query('`endowment-fy-begin` != 2019').copy()
harvard_end_adm
# Out:
#     endowment-fy-begin  endowment-pct-chg  ug-admitted-pct-chg
# 43                2020             0.0244               0.0030
# 42                2021             0.2697               0.1504
# 41                2022            -0.0432              -0.1441
# 40                2023            -0.0039              -0.0096

# %%
# converting total endowment and total admittance to long data for multiline plot
harvard_end_adm_long = harvard_end_adm.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ug-admitted-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
harvard_end_adm_long = harvard_end_adm_long.assign(Type=harvard_end_adm_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ug-admitted-pct-chg' : 'Admitted'}))

# %%
# sort by year (endowment-fy-begin) ASC
harvard_end_adm_long = harvard_end_adm_long.sort_values(by=['endowment-fy-begin'])
harvard_end_adm_long
# Out:
#    endowment-fy-begin                 type  percentage       Type
# 0                2020    endowment-pct-chg      0.0244  Endowment
# 4                2020  ug-admitted-pct-chg      0.0030   Admitted
# 1                2021    endowment-pct-chg      0.2697  Endowment
# 5                2021  ug-admitted-pct-chg      0.1504   Admitted
# 2                2022    endowment-pct-chg     -0.0432  Endowment
# 6                2022  ug-admitted-pct-chg     -0.1441   Admitted
# 3                2023    endowment-pct-chg     -0.0039  Endowment
# 7                2023  ug-admitted-pct-chg     -0.0096   Admitted

# %%
# creating dataframe for admitted coordinates
harvard_adm_coord = harvard_end_adm_long[(harvard_end_adm_long.Type == 'Admitted')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
harvard_adm_coord['percentage'] = harvard_adm_coord['percentage'].apply(lambda x: round(x, 4))
harvard_adm_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020      0.0030
# 5                2021      0.1504
# 6                2022     -0.1441
# 7                2023     -0.0096

# %%
# plotting total admittance and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
harvard_end_adm_plot = sns.lineplot(harvard_end_adm_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(harvard_end_adm_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points (reusing coordinates already created in total endowment vs. total enrollment)
for i, point in harvard_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.125, str(point["percentage"]))

# annotate admittance points
for i, point in harvard_adm_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.125, str(point["percentage"]))


ax.set_title('2020-2023 Harvard Total Endowment vs. First-Time Admittance YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ### 9) Williams College

# %%
# creating dataframe with only total endowment & total admittance percentage changes
williams_end_adm = williams_df[['endowment-fy-begin', 'endowment-pct-chg', 'ug-admitted-pct-chg']]

# %%
# removing year 2019 due to all 0 values
williams_end_adm = williams_end_adm.query('`endowment-fy-begin` != 2019').copy()
williams_end_adm
# Out:
#     endowment-fy-begin  endowment-pct-chg  ug-admitted-pct-chg
# 48                2020            -0.0345               0.0801
# 47                2021             0.5000              -0.1687
# 46                2022            -0.1667               0.1847
# 45                2023             0.0000              -0.1206

# %%
# converting total endowment and total admittance to long data for multiline plot
williams_end_adm_long = williams_end_adm.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ug-admitted-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
williams_end_adm_long = williams_end_adm_long.assign(Type=williams_end_adm_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ug-admitted-pct-chg' : 'Admitted'}))

# %%
# sort by year (endowment-fy-begin) ASC
williams_end_adm_long = williams_end_adm_long.sort_values(by=['endowment-fy-begin'])
williams_end_adm_long
# Out:
#    endowment-fy-begin                 type  percentage       Type
# 0                2020    endowment-pct-chg     -0.0345  Endowment
# 4                2020  ug-admitted-pct-chg      0.0801   Admitted
# 1                2021    endowment-pct-chg      0.5000  Endowment
# 5                2021  ug-admitted-pct-chg     -0.1687   Admitted
# 2                2022    endowment-pct-chg     -0.1667  Endowment
# 6                2022  ug-admitted-pct-chg      0.1847   Admitted
# 3                2023    endowment-pct-chg      0.0000  Endowment
# 7                2023  ug-admitted-pct-chg     -0.1206   Admitted

# %%
# creating dataframe for admitted coordinates
williams_adm_coord = williams_end_adm_long[(williams_end_adm_long.Type == 'Admitted')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
williams_adm_coord['percentage'] = williams_adm_coord['percentage'].apply(lambda x: round(x, 4))
williams_adm_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020      0.0801
# 5                2021     -0.1687
# 6                2022      0.1847
# 7                2023     -0.1206

# %%
# plotting total admittance and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
williams_end_adm_plot = sns.lineplot(williams_end_adm_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(williams_end_adm_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points (reusing coordinates already created in total endowment vs. total enrollment)
for i, point in williams_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.09, str(point["percentage"]))

# annotate admittance points
for i, point in williams_adm_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.09, str(point["percentage"]))


ax.set_title('2020-2023 Williams College Total Endowment vs. First-Time Admittance YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ### 10) Amherst College

# %%
# creating dataframe with only total endowment & total admittance percentage changes
amherst_end_adm = amherst_df[['endowment-fy-begin', 'endowment-pct-chg', 'ug-admitted-pct-chg']]

# %%
# removing year 2019 due to all 0 values
amherst_end_adm = amherst_end_adm.query('`endowment-fy-begin` != 2019').copy()
amherst_end_adm
# Out:
#     endowment-fy-begin  endowment-pct-chg  ug-admitted-pct-chg
# 53                2020             0.2738               0.0494
# 52                2021             0.4698              -0.0239
# 51                2022            -0.1274              -0.1185
# 50                2023             0.0050               0.1585

# %%
# converting total endowment and total admittance to long data for multiline plot
amherst_end_adm_long = amherst_end_adm.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ug-admitted-pct-chg'], \
                                                  var_name='type', value_name='percentage')

# %%
# creating column with nomenclature reassignments, for plot's legend
amherst_end_adm_long = amherst_end_adm_long.assign(Type=amherst_end_adm_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ug-admitted-pct-chg' : 'Admitted'}))

# %%
# sort by year (endowment-fy-begin) ASC
amherst_end_adm_long = amherst_end_adm_long.sort_values(by=['endowment-fy-begin'])
amherst_end_adm_long
# Out:
#    endowment-fy-begin                 type  percentage       Type
# 0                2020    endowment-pct-chg      0.2738  Endowment
# 4                2020  ug-admitted-pct-chg      0.0494   Admitted
# 1                2021    endowment-pct-chg      0.4698  Endowment
# 5                2021  ug-admitted-pct-chg     -0.0239   Admitted
# 2                2022    endowment-pct-chg     -0.1274  Endowment
# 6                2022  ug-admitted-pct-chg     -0.1185   Admitted
# 3                2023    endowment-pct-chg      0.0050  Endowment
# 7                2023  ug-admitted-pct-chg      0.1585   Admitted

# %%
# creating dataframe for admitted coordinates
amherst_adm_coord = amherst_end_adm_long[(amherst_end_adm_long.Type == 'Admitted')][['endowment-fy-begin', 'percentage']]
# truncating decimal to 4 places
amherst_adm_coord['percentage'] = amherst_adm_coord['percentage'].apply(lambda x: round(x, 4))
amherst_adm_coord
# Out:
#    endowment-fy-begin  percentage
# 4                2020      0.0494
# 5                2021     -0.0239
# 6                2022     -0.1185
# 7                2023      0.1585

# %%
# plotting total admittance and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
amherst_end_adm_plot = sns.lineplot(amherst_end_adm_long, x='endowment-fy-begin', y='percentage', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(amherst_end_adm_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points (reusing coordinates already created in total endowment vs. total enrollment)
for i, point in amherst_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]-.09, str(point["percentage"]))

# annotate admittance points
for i, point in amherst_adm_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["percentage"]+.05, str(point["percentage"]))


ax.set_title('2020-2023 Amherst College Total Endowment vs. First-Time Admittance YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# # **Curious Analysis**

# %%
merged_df.head(1)
# Out:
#    ranking-2023            university state                    type  \
# 0             1  Princeton University    NJ  Private-not-for-profit
#
#    endowment-fy-begin  endowment-amount  ug-enrollment-year  \
# 0                2023       35800000000                2023
#
#    ug-enrolled-total  ug-first-time-enrolled  ug-first-time-admitted  \
# 0               5598              1,366.0000              1,782.0000
#
#          end-yoy-diff  ug-enrtotal-yoy-diff  ug-first-time-enr-yoy-diff  \
# 0 -1,900,000,000.0000               58.0000                   -131.0000
#
#    ug-first-time-adm-yoy-diff  endowment-pct-chg  ugtotal-pct-chg  \
# 0                   -385.0000            -0.0504           0.0105
#
#    ugfirst-time-pct-chg  ug-admitted-pct-chg
# 0               -0.0875              -0.1777

# %%
merged_df.describe()
# Out:
#        ranking-2023  endowment-fy-begin    endowment-amount  \
# count       50.0000             50.0000             50.0000
# mean         6.0000          2,021.0000 22,412,412,000.0000
# std          3.3503              1.4286 15,155,621,304.5724
# min          1.0000          2,019.0000  2,473,000,000.0000
# 25%          3.0000          2,020.0000  5,025,000,000.0000
# 50%          6.0000          2,021.0000 22,900,000,000.0000
# 75%          9.0000          2,022.0000 30,979,975,000.0000
# max         11.0000          2,023.0000 53,200,000,000.0000
#
#        ug-enrollment-year  ug-enrolled-total  ug-first-time-enrolled  \
# count             50.0000            50.0000                 50.0000
# mean           2,021.0000        10,826.8200              2,368.6400
# std                1.4286        11,019.7049              2,149.2510
# min            2,019.0000         1,745.0000                434.0000
# 25%            2,020.0000         4,591.5000              1,110.5000
# ...

# %% [markdown]
# ### Checking Outliers

# %% [markdown]
# #### Total Endowment Pct. Change

# %%
# checking for outliers in total endowment percentage change
sns.boxplot(x=merged_df['endowment-pct-chg'])
# Out:
# <Axes: xlabel='endowment-pct-chg'>

# %% [markdown]
# #### Total Undergraduate Enrollment Pct. Change

# %%
# checking for outliers in total enrollment percentage change
sns.boxplot(x=merged_df['ugtotal-pct-chg'], fliersize=1)
# Out:
# <Axes: xlabel='ugtotal-pct-chg'>

# %% [markdown]
# - Can likely normalize, since reasons for enrollment can vary based on relative features - e.g., the "social prestigiousness rank" of the university/college.
#
# #### ***Boxplot Limits:***

# %%
# split into 25th and 75th percentiles
ugtotal_perc_25 = merged_df['ugtotal-pct-chg'].quantile(0.25)
ugtotal_perc_75 = merged_df['ugtotal-pct-chg'].quantile(0.75)

# calculate iqr
ugtotal_iqr = ugtotal_perc_75 - ugtotal_perc_25

# determine upper limit
ugtotal_upper_limit = ugtotal_perc_75 + 1.5 * ugtotal_iqr

# determine lower limit
ugtotal_lower_limit = ugtotal_perc_25 - 1.5 * ugtotal_iqr

# storing outliers & printing total number
ugtotal_outliers = merged_df[(merged_df['ugtotal-pct-chg'] > ugtotal_upper_limit) | (merged_df['ugtotal-pct-chg'] < ugtotal_lower_limit)]
print(f'Undergrad Total Num. of Outliers: {len(ugtotal_outliers)}')
# Out:
# Undergrad Total Num. of Outliers: 8

# %% [markdown]
# Box plot displays 7 points, whereas the total number found after storing in new dataframe, is 8. After investigation, there are two relatively close points at -.2280 and -.2269. *Assuming that fitting the x-scale will cause all points to be displayed.*

# %%
ugtotal_outliers[['university', 'ugtotal-pct-chg']].sort_values(by=['ugtotal-pct-chg'])
# Out:
#               university  ugtotal-pct-chg
# 8        Yale University          -0.2280
# 38    Harvard University          -0.2269
# 3   Princeton University          -0.1201
# 2   Princeton University           0.1177
# 47       Amherst College           0.1295
# 12   Stanford University           0.2009
# 37    Harvard University           0.3698
# 7        Yale University           0.3898

# %% [markdown]
# #### Total Undergraduate First-Time Enrollment Pct. Change

# %%
# checking for outliers in total undergrad first-time enrollment percentage change
sns.boxplot(x=merged_df['ugfirst-time-pct-chg'])
# Out:
# <Axes: xlabel='ugfirst-time-pct-chg'>

# %% [markdown]
# - Decided to normalize due to the minute number of outliers in its regard to first-time enrollment. This could be due to a social uptick of the university, for example (conjecture).
#
# #### ***Boxplot Limits:***

# %%
# split into 25th and 75th percentiles
ugfirst_perc_25 = merged_df['ugfirst-time-pct-chg'].quantile(0.25)
ugfirst_perc_75 = merged_df['ugfirst-time-pct-chg'].quantile(0.75)

# calculate iqr
ugfirst_iqr = ugfirst_perc_75 - ugfirst_perc_25

# determine upper limit
ugfirst_upper_limit = ugfirst_perc_75 + 1.5 * ugfirst_iqr

# storing outliers & printing total number
ugfirst_outliers = merged_df[(merged_df['ugfirst-time-pct-chg'] > ugfirst_upper_limit)]
print(f'Undergrad Total Num. of Outliers: {len(ugfirst_outliers)}')
# Out:
# Undergrad Total Num. of Outliers: 2

# %% [markdown]
# #### Total Undergraduate First-Time Admittance Pct. Change

# %%
# checking for outliers in total undergrad first-time admittance percentage change
sns.boxplot(x=merged_df['ug-admitted-pct-chg'])
# Out:
# <Axes: xlabel='ug-admitted-pct-chg'>

# %% [markdown]
# - Decided to normalize due to the minute number of outliers in its regard to first-time admittance. There can be various reasons as to why a university/college decided to admit more students than usual; nonetheless it would likely be adavantageous to avoid having one outlier bias the whole data subset.
#
# #### ***Boxplot Limits:***

# %%
# split into 25th and 75th percentiles
ugadm_perc_25 = merged_df['ug-admitted-pct-chg'].quantile(0.25)
ugadm_perc_75 = merged_df['ug-admitted-pct-chg'].quantile(0.75)

# calculate iqr
ugadm_iqr = ugadm_perc_75 - ugadm_perc_25

# determine upper limit
ugadm_upper_limit = ugadm_perc_75 + 1.5 * ugadm_iqr

# storing outliers & printing total number
ugadm_outliers = merged_df[(merged_df['ug-admitted-pct-chg'] > ugadm_upper_limit)]
print(f'Undergrad Total Num. of Outliers: {len(ugadm_outliers)}')
# Out:
# Undergrad Total Num. of Outliers: 1

# %% [markdown]
# ### Outlier Handling

# %%
merged_df.shape
# Out:
# (50, 18)

# %%
# removing total undergraduate enrollment outliers
out_merged_df = merged_df[(merged_df['ugtotal-pct-chg'] <= ugtotal_upper_limit) | (merged_df['ugtotal-pct-chg'] >= ugtotal_lower_limit)]

# removing total undergraduate first-time enrollment outliers
out_merged_df = merged_df[(merged_df['ugfirst-time-pct-chg'] <= ugfirst_upper_limit)]

# removing total undergraduate first-time admission outliers
out_merged_df = merged_df[(merged_df['ug-admitted-pct-chg'] <= ugadm_upper_limit)]

# %%
# confirming 11 removed outliers
out_merged_df.shape
# Out:
# (39, 18)

# %% [markdown]
# ## 1) Overall Universities | Total Endowment vs. Total Undergrad Enrollment

# %%
end_enr_total_df = out_merged_df.groupby(['endowment-fy-begin'])[['endowment-pct-chg', 'ugtotal-pct-chg']].sum().reset_index()

# %%
# removing year 2019 due to all 0 values
end_enr_total_df = end_enr_total_df.query('`endowment-fy-begin` != 2019').copy()
end_enr_total_df
# Out:
#    endowment-fy-begin  endowment-pct-chg  ugtotal-pct-chg
# 0                2020             0.5009          -0.8328
# 1                2021             3.0623           1.4371
# 2                2022             0.2060           0.0529
# 3                2023            -0.0037           0.0154

# %%
# converting total endowment and total enrollment to long data for multiline plot
end_enr_total_long = end_enr_total_df.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ugtotal-pct-chg'], \
                                                  var_name='type', value_name='tot-percent')

# %%
# creating column with nomenclature reassignments, for plot's legend
end_enr_total_long = end_enr_total_long.assign(Type=end_enr_total_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ugtotal-pct-chg' : 'Enrollment'}))

# %%
# sort by year (endowment-fy-begin) ASC
end_enr_total_long = end_enr_total_long.sort_values(by=['endowment-fy-begin'])
end_enr_total_long
# Out:
#    endowment-fy-begin               type  tot-percent        Type
# 0                2020  endowment-pct-chg       0.5009   Endowment
# 4                2020    ugtotal-pct-chg      -0.8328  Enrollment
# 1                2021  endowment-pct-chg       3.0623   Endowment
# 5                2021    ugtotal-pct-chg       1.4371  Enrollment
# 2                2022  endowment-pct-chg       0.2060   Endowment
# 6                2022    ugtotal-pct-chg       0.0529  Enrollment
# 3                2023  endowment-pct-chg      -0.0037   Endowment
# 7                2023    ugtotal-pct-chg       0.0154  Enrollment

# %%
# creating dataframe for endowment coordinates
tot_end_coord = end_enr_total_long[(end_enr_total_long.Type == 'Endowment')][['endowment-fy-begin', 'tot-percent']]
# truncating decimal to 4 places
tot_end_coord['tot-percent'] = tot_end_coord['tot-percent'].apply(lambda x: round(x, 4))
tot_end_coord
# Out:
#    endowment-fy-begin  tot-percent
# 0                2020       0.5009
# 1                2021       3.0623
# 2                2022       0.2060
# 3                2023      -0.0037

# %%
# creating dataframe for enrollment coordinates
tot_enr_coord = end_enr_total_long[(end_enr_total_long.Type == 'Enrollment')][['endowment-fy-begin', 'tot-percent']]
# truncating decimal to 4 places
tot_enr_coord['tot-percent'] = tot_enr_coord['tot-percent'].apply(lambda x: round(x, 4))
tot_enr_coord
# Out:
#    endowment-fy-begin  tot-percent
# 4                2020      -0.8328
# 5                2021       1.4371
# 6                2022       0.0529
# 7                2023       0.0154

# %%
# plotting total enrollment and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
endenrtot_plot = sns.lineplot(end_enr_total_long, x='endowment-fy-begin', y='tot-percent', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(end_enr_total_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=4)

# annotate endowment points
for i, point in tot_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["tot-percent"]+.125, str(point["tot-percent"]))

# annotate enrollment points
for i, point in tot_enr_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["tot-percent"]-.125, str(point["tot-percent"]))


ax.set_title('2020-2023 Overall Total Endowment vs. Total Undergrad Enrollment YoY Percentage Change')
ax.set_ylabel('Total Percent Change')
ax.set_xlabel('Year')

plt.show(endenrtot_plot)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ## 2) Overall Universities | Average Total Endowment vs. Average Total Undergrad Enrollment

# %%
end_enr_avg_df = out_merged_df.groupby(['endowment-fy-begin'])[['endowment-pct-chg', 'ugtotal-pct-chg']].mean().reset_index()

# %%
# removing year 2019 due to all 0 values
end_enr_avg_df = end_enr_avg_df.query('`endowment-fy-begin` != 2019').copy()
end_enr_avg_df
# Out:
#    endowment-fy-begin  endowment-pct-chg  ugtotal-pct-chg
# 0                2020             0.0501          -0.0833
# 1                2021             0.3062           0.1437
# 2                2022             0.0229           0.0059
# 3                2023            -0.0004           0.0015

# %%
# converting total endowment and total enrollment to long data for multiline plot
end_enr_avg_long = end_enr_avg_df.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ugtotal-pct-chg'], \
                                                  var_name='type', value_name='avg-percent')

# %%
# creating column with nomenclature reassignments, for plot's legend
end_enr_avg_long = end_enr_avg_long.assign(Type=end_enr_avg_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ugtotal-pct-chg' : 'Enrollment'}))

# %%
# sort by year (endowment-fy-begin) ASC
end_enr_avg_long = end_enr_avg_long.sort_values(by=['endowment-fy-begin'])
end_enr_avg_long
# Out:
#    endowment-fy-begin               type  avg-percent        Type
# 0                2020  endowment-pct-chg       0.0501   Endowment
# 4                2020    ugtotal-pct-chg      -0.0833  Enrollment
# 1                2021  endowment-pct-chg       0.3062   Endowment
# 5                2021    ugtotal-pct-chg       0.1437  Enrollment
# 2                2022  endowment-pct-chg       0.0229   Endowment
# 6                2022    ugtotal-pct-chg       0.0059  Enrollment
# 3                2023  endowment-pct-chg      -0.0004   Endowment
# 7                2023    ugtotal-pct-chg       0.0015  Enrollment

# %%
# creating dataframe for endowment coordinates
avg_end_coord = end_enr_avg_long[(end_enr_avg_long.Type == 'Endowment')][['endowment-fy-begin', 'avg-percent']]
# truncating decimal to 4 places
avg_end_coord['avg-percent'] = avg_end_coord['avg-percent'].apply(lambda x: round(x, 4))
avg_end_coord
# Out:
#    endowment-fy-begin  avg-percent
# 0                2020       0.0501
# 1                2021       0.3062
# 2                2022       0.0229
# 3                2023      -0.0004

# %%
# creating dataframe for enrollment coordinates
avg_enr_coord = end_enr_avg_long[(end_enr_avg_long.Type == 'Enrollment')][['endowment-fy-begin', 'avg-percent']]
# truncating decimal to 4 places
avg_enr_coord['avg-percent'] = avg_enr_coord['avg-percent'].apply(lambda x: round(x, 4))
avg_enr_coord
# Out:
#    endowment-fy-begin  avg-percent
# 4                2020      -0.0833
# 5                2021       0.1437
# 6                2022       0.0059
# 7                2023       0.0015

# %%
# plotting total enrollment and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
end_enr_avg_plot = sns.lineplot(end_enr_avg_long, x='endowment-fy-begin', y='avg-percent', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(end_enr_avg_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points
for i, point in avg_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["avg-percent"]+.125, str(point["avg-percent"]))

# annotate enrollment points
for i, point in avg_enr_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["avg-percent"]-.125, str(point["avg-percent"]))


ax.set_title('2020-2023 Avg. Endowment vs. Avg. Undergrad Enrollment YoY Percentage Change')
ax.set_ylabel('Avg. Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ## 3) Overall Universities | Total Endowment vs. Total Undergrads Admitted

# %%
end_adm_tot_df = out_merged_df.groupby(['endowment-fy-begin'])[['endowment-pct-chg', 'ug-admitted-pct-chg']].sum().reset_index()

# %%
# removing year 2019 due to all 0 values
end_adm_tot_df = end_adm_tot_df.query('`endowment-fy-begin` != 2019').copy()
end_adm_tot_df
# Out:
#    endowment-fy-begin  endowment-pct-chg  ug-admitted-pct-chg
# 0                2020             0.5009               0.6324
# 1                2021             3.0623              -0.3291
# 2                2022             0.2060              -0.4127
# 3                2023            -0.0037              -0.1747

# %%
# converting total endowment and total enrollment to long data for multiline plot
end_adm_tot_long = end_adm_tot_df.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ug-admitted-pct-chg'], \
                                                  var_name='type', value_name='tot-percent')

# %%
# creating column with nomenclature reassignments, for plot's legend
end_adm_tot_long = end_adm_tot_long.assign(Type=end_adm_tot_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ug-admitted-pct-chg' : 'Admission'}))

# %%
# sort by year (endowment-fy-begin) ASC
end_adm_tot_long = end_adm_tot_long.sort_values(by=['endowment-fy-begin'])
end_adm_tot_long
# Out:
#    endowment-fy-begin                 type  tot-percent       Type
# 0                2020    endowment-pct-chg       0.5009  Endowment
# 4                2020  ug-admitted-pct-chg       0.6324  Admission
# 1                2021    endowment-pct-chg       3.0623  Endowment
# 5                2021  ug-admitted-pct-chg      -0.3291  Admission
# 2                2022    endowment-pct-chg       0.2060  Endowment
# 6                2022  ug-admitted-pct-chg      -0.4127  Admission
# 3                2023    endowment-pct-chg      -0.0037  Endowment
# 7                2023  ug-admitted-pct-chg      -0.1747  Admission

# %%
# creating dataframe for admission coordinates
tot_adm_coord = end_adm_tot_long[(end_adm_tot_long.Type == 'Admission')][['endowment-fy-begin', 'tot-percent']]
# truncating decimal to 4 places
tot_adm_coord['tot-percent'] = tot_adm_coord['tot-percent'].apply(lambda x: round(x, 4))
tot_adm_coord
# Out:
#    endowment-fy-begin  tot-percent
# 4                2020       0.6324
# 5                2021      -0.3291
# 6                2022      -0.4127
# 7                2023      -0.1747

# %%
# plotting total enrollment and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
end_adm_tot_plot = sns.lineplot(end_adm_tot_long, x='endowment-fy-begin', y='tot-percent', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(end_adm_tot_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=4)

# annotate endowment points (reusing total endowment coordinates in #1)
for i, point in tot_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["tot-percent"]+.125, str(point["tot-percent"]))

# annotate admission points
for i, point in tot_adm_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["tot-percent"]-.125, str(point["tot-percent"]))


ax.set_title('2020-2023 Total Endowment vs. Total Undergrad Admission YoY Percentage Change')
ax.set_ylabel('Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ## 4) Overall Universities | Average Total Endowment vs. Average Total Undergrads Admitted

# %%
end_adm_avg_df = out_merged_df.groupby(['endowment-fy-begin'])[['endowment-pct-chg', 'ug-admitted-pct-chg']].mean().reset_index()

# %%
# removing year 2019 due to all 0 values
end_adm_avg_df = end_adm_avg_df.query('`endowment-fy-begin` != 2019').copy()
end_adm_avg_df
# Out:
#    endowment-fy-begin  endowment-pct-chg  ug-admitted-pct-chg
# 0                2020             0.0501               0.0632
# 1                2021             0.3062              -0.0329
# 2                2022             0.0229              -0.0459
# 3                2023            -0.0004              -0.0175

# %%
# converting total endowment and total enrollment to long data for multiline plot
end_adm_avg_long = end_adm_avg_df.copy().melt(id_vars=['endowment-fy-begin'], value_vars=['endowment-pct-chg', 'ug-admitted-pct-chg'], \
                                                  var_name='type', value_name='avg-percent')

# %%
# creating column with nomenclature reassignments, for plot's legend
end_adm_avg_long = end_adm_avg_long.assign(Type=end_adm_avg_long.type.map({'endowment-pct-chg': 'Endowment', \
                                                                           'ug-admitted-pct-chg' : 'Admission'}))

# %%
# sort by year (endowment-fy-begin) ASC
end_adm_avg_long = end_adm_avg_long.sort_values(by=['endowment-fy-begin'])
end_adm_avg_long
# Out:
#    endowment-fy-begin                 type  avg-percent       Type
# 0                2020    endowment-pct-chg       0.0501  Endowment
# 4                2020  ug-admitted-pct-chg       0.0632  Admission
# 1                2021    endowment-pct-chg       0.3062  Endowment
# 5                2021  ug-admitted-pct-chg      -0.0329  Admission
# 2                2022    endowment-pct-chg       0.0229  Endowment
# 6                2022  ug-admitted-pct-chg      -0.0459  Admission
# 3                2023    endowment-pct-chg      -0.0004  Endowment
# 7                2023  ug-admitted-pct-chg      -0.0175  Admission

# %%
# creating dataframe for enrollment coordinates
avg_adm_coord = end_adm_avg_long[(end_adm_avg_long.Type == 'Admission')][['endowment-fy-begin', 'avg-percent']]
# truncating decimal to 4 places
avg_adm_coord['avg-percent'] = avg_adm_coord['avg-percent'].apply(lambda x: round(x, 4))
avg_adm_coord
# Out:
#    endowment-fy-begin  avg-percent
# 4                2020       0.0632
# 5                2021      -0.0329
# 6                2022      -0.0459
# 7                2023      -0.0175

# %%
# plotting total enrollment and total endowment in one plot
fig, ax = plt.subplots(figsize=(11,5))

# creating lineplot
end_adm_avg_plot = sns.lineplot(end_adm_avg_long, x='endowment-fy-begin', y='avg-percent', hue='Type')

# setting x-axis ticks to endowment years
ax.set_xticks(end_adm_avg_long['endowment-fy-begin'].unique())
# setting y-axis limits
ax.set_ylim(bottom=-1, top=1)

# annotate endowment points (reusing from already-created coordinates in #2)
for i, point in avg_end_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["avg-percent"]+.125, str(point["avg-percent"]))

# annotate enrollment points
for i, point in avg_adm_coord.iterrows():
    ax.text(point["endowment-fy-begin"]-.09, point["avg-percent"]-.125, str(point["avg-percent"]))


ax.set_title('2020-2023 Avg. Endowment vs. Avg. Undergrads Admitted YoY Percentage Change')
ax.set_ylabel('Avg. Percent Change')
ax.set_xlabel('Year')

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ## Insights/Takeaways
#
# 1) Overall Universities | Total Endowment vs. Total Enrollment
#     - Although the line plot looks to be following a correlated pattern of increases/decreases in endowment having the same pattern as increases/decreases in enrollment, these seem to be the cause of small changes in percentage rates. E.g., *Enrollment* from 2022-2023 reflecting a .0154% increase but when compared to the -.0037 *Endowment* change over the same period, they may appear to follow the same trend.
#     - One of the more glaring observations in this plot is the (technically) 306% increase of total endowment from 2020 to 2021, following the general trend observed in the relative university/college analysis, of 70% universities/colleges experiencing relatively large endowment increases during the aforementioned time period.
#
# 2) Overall Universities | Total Avg. Endowment vs. Total Avg. Undergrad Enrollment
#     - The only observable similarity seems to be the relatively large-to-small increases covering the periods from 2020-2021, 2021-2022 respectively.
#
# 3) Overall Universities | Total Endowment vs. Total Undergrads Admitted
#     - Aside from the endowment change from 2020-2021 (already mentioned in #1), it may be interesting to note that despite this large increase, there's an observed total decrease in undergrad admissions.
#
# 4) Overall Universities | Avg. Endowment vs. Avg. Undergrads Admitted
#     - Observations of periods 2020-2021 and 2021-2022 having decreases in average undergraduate admission, while the average endowment experienced increases.
#
# - Overall, it may be advantageous to investigate the cause in the 2020-2021 spike for university/college endowment, as well as the observerd decreases in Undergraduate Admissions for the same period & determine if there is/are any correlation.
